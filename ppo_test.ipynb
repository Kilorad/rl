# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# multiprocess environment
env = make_vec_env('CartPole-v1', n_envs=4)

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")

del model # remove to demonstrate saving and loading

model = PPO2.load("ppo2_cartpole")

# Enjoy trained agent
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    #env.render()

# %%
import sys
sys.path.insert(1, './env')
sys.path.insert(1, './agents')
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import aa_gun
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

report = []

done_max = 5
resets_max = 140

for estimation in range(done_max):
    # multiprocess environment
    env=aa_gun.AA_gun_simple0_env(fast_planes=False,long_projectiles=False,random_speed=False)
    #env = make_vec_env('Seaquest-ramNoFrameskip-v0', n_envs=3)
    #env = make_vec_env(env, n_envs=4)

    model = PPO2(MlpPolicy, env, verbose=0)
    model.learn(total_timesteps=0)
    

    # Enjoy trained agent
    
    obs = env.reset()
    episode=0
    rew_episodes=[]
    reward_list=[]
    print('ESIMATION',estimation)
    while True:
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        reward_list.append(rewards)
        #env.render()
        if np.any(dones):
            rew_episodes.append(np.sum(reward_list))
            print('EPISODE',episode,'rew',np.sum(reward_list),dones)
            obs = env.reset()
            reward_list=[]
            episode+=1
        if episode>resets_max:
            break
    report.append(np.mean(rew_episodes))
    plt.plot(rew_episodes)
    plt.show()
# Out:
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088447cc18>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088447cc18>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088447cc18>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088447cc18>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c8223f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c8223f60>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c8223f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c8223f60>>: AttributeError: module 'gast' has no attribute 'Num'
# ESIMATION 0
# EPISODE 0 rew 1.3125 True
# hit
# EPISODE 1 rew 2.375 True
# EPISODE 2 rew 0.8125 True
# hit
# EPISODE 3 rew 1.25 True
# hit
# EPISODE 4 rew 1.75 True
# EPISODE 5 rew 0.125 True
# EPISODE 6 rew 0.875 True
# hit
# EPISODE 7 rew 1.5625 True
# EPISODE 8 rew 0.4375 True
# hit
# EPISODE 9 rew 3.0625 True
# EPISODE 10 rew 0 True
# hit
# EPISODE 11 rew 1.5 True
# hit
# EPISODE 12 rew 1.75 True
# hit
# EPISODE 13 rew 1.75 True
# EPISODE 14 rew 0.6875 True
# hit
# EPISODE 15 rew 2.5625 True
# EPISODE 16 rew 0.4375 True
# hit
# EPISODE 17 rew 1.25 True
# EPISODE 18 rew 1.0 True
# EPISODE 19 rew 1.1875 True
# hit
# EPISODE 20 rew 1.6875 True
# EPISODE 21 rew 0.8125 True
# hit
# EPISODE 22 rew 1.4375 True
# hit
# EPISODE 23 rew 2.1875 True
# EPISODE 24 rew 0.9375 True
# EPISODE 25 rew 1.1875 True
# EPISODE 26 rew 1.1875 True
# hit
# EPISODE 27 rew 2.25 True
# hit
# EPISODE 28 rew 1.125 True
# hit
# EPISODE 29 rew 1.5625 True
# EPISODE 30 rew 1.0625 True
# hit
# hit
# EPISODE 31 rew 2.5 True
# EPISODE 32 rew 1.0 True
# hit
# hit
# hit
# EPISODE 33 rew 4.25 True
# EPISODE 34 rew 0.625 True
# EPISODE 35 rew 0.875 True
# hit
# EPISODE 36 rew 1.25 True
# EPISODE 37 rew 1.0 True
# hit
# hit
# EPISODE 38 rew 2.75 True
# hit
# EPISODE 39 rew 1.8125 True
# EPISODE 40 rew 0.4375 True
# EPISODE 41 rew 0.625 True
# EPISODE 42 rew 0.6875 True
# EPISODE 43 rew 0.875 True
# hit
# EPISODE 44 rew 2.8125 True
# EPISODE 45 rew 1.1875 True
# EPISODE 46 rew 0.6875 True
# hit
# hit
# EPISODE 47 rew 3.0 True
# EPISODE 48 rew 1.125 True
# EPISODE 49 rew 0.9375 True
# EPISODE 50 rew 0.4375 True
# hit
# EPISODE 51 rew 1.125 True
# EPISODE 52 rew 2.125 True
# EPISODE 53 rew 0.9375 True
# hit
# EPISODE 54 rew 2.0 True
# hit
# EPISODE 55 rew 1.375 True
# EPISODE 56 rew 0.8125 True
# EPISODE 57 rew 1.1875 True
# hit
# EPISODE 58 rew 2.25 True
# EPISODE 59 rew 1.1875 True
# EPISODE 60 rew 1.125 True
# EPISODE 61 rew 1.4375 True
# hit
# EPISODE 62 rew 1.1875 True
# EPISODE 63 rew 0.625 True
# EPISODE 64 rew 1.5625 True
# EPISODE 65 rew 2.0625 True
# EPISODE 66 rew 1.0 True
# hit
# hit
# EPISODE 67 rew 2.375 True
# hit
# EPISODE 68 rew 1.6875 True
# hit
# EPISODE 69 rew 2.75 True
# EPISODE 70 rew 0.6875 True
# hit
# EPISODE 71 rew 1.5 True
# hit
# EPISODE 72 rew 1.4375 True
# EPISODE 73 rew 0.625 True
# EPISODE 74 rew 0.5 True
# EPISODE 75 rew 1.0625 True
# hit
# EPISODE 76 rew 1.125 True
# EPISODE 77 rew 1.8125 True
# hit
# EPISODE 78 rew 1.3125 True
# hit
# EPISODE 79 rew 2.125 True
# EPISODE 80 rew 0.6875 True
# EPISODE 81 rew 1.4375 True
# EPISODE 82 rew 1.0625 True
# EPISODE 83 rew 1.6875 True
# EPISODE 84 rew 0.25 True
# EPISODE 85 rew 0.625 True
# EPISODE 86 rew 0.6875 True
# hit
# EPISODE 87 rew 1.5625 True
# EPISODE 88 rew 0.5 True
# hit
# EPISODE 89 rew 2.25 True
# EPISODE 90 rew 1.1875 True
# EPISODE 91 rew 0 True
# EPISODE 92 rew 0 True
# hit
# EPISODE 93 rew 2.125 True
# hit
# EPISODE 94 rew 2.125 True
# EPISODE 95 rew 1.0625 True
# EPISODE 96 rew 1.4375 True
# EPISODE 97 rew 0.125 True
# hit
# EPISODE 98 rew 1 True
# EPISODE 99 rew 1.5 True
# hit
# hit
# EPISODE 100 rew 2.375 True
# EPISODE 101 rew 1.625 True
# EPISODE 102 rew 0.6875 True
# hit
# EPISODE 103 rew 1.5625 True
# EPISODE 104 rew 1.3125 True
# EPISODE 105 rew 0.875 True
# EPISODE 106 rew 1.625 True
# hit
# EPISODE 107 rew 1.3125 True
# EPISODE 108 rew 1.625 True
# hit
# EPISODE 109 rew 1.0625 True
# EPISODE 110 rew 1.125 True
# EPISODE 111 rew 1.1875 True
# hit
# EPISODE 112 rew 1.0625 True
# EPISODE 113 rew 1.375 True
# EPISODE 114 rew 0.9375 True
# EPISODE 115 rew 1.375 True
# EPISODE 116 rew 0.5 True
# EPISODE 117 rew 1.5625 True
# EPISODE 118 rew 0.3125 True
# EPISODE 119 rew 1.0625 True
# EPISODE 120 rew 1.0625 True
# EPISODE 121 rew 0.9375 True
# hit
# EPISODE 122 rew 1.25 True
# EPISODE 123 rew 0.875 True
# EPISODE 124 rew 0.875 True
# hit
# EPISODE 125 rew 2.25 True
# hit
# EPISODE 126 rew 2.5 True
# EPISODE 127 rew 0.25 True
# EPISODE 128 rew 0.375 True
# hit
# EPISODE 129 rew 1.0625 True
# EPISODE 130 rew 0.25 True
# hit
# EPISODE 131 rew 2.0 True
# EPISODE 132 rew 1.4375 True
# EPISODE 133 rew 0.875 True
# hit
# EPISODE 134 rew 1.5625 True
# EPISODE 135 rew 0.3125 True
# EPISODE 136 rew 0.9375 True
# EPISODE 137 rew 0.875 True
# EPISODE 138 rew 0.6875 True
# EPISODE 139 rew 0.875 True
# EPISODE 140 rew 0.75 True
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0884279780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0884279780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0884279780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0884279780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c81e0780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c81e0780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c81e0780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c81e0780>>: AttributeError: module 'gast' has no attribute 'Num'
# ESIMATION 1
# hit
# EPISODE 0 rew 2.125 True
# hit
# EPISODE 1 rew 1.25 True
# hit
# EPISODE 2 rew 1.875 True
# EPISODE 3 rew 0.25 True
# hit
# EPISODE 4 rew 1.75 True
# EPISODE 5 rew 0.9375 True
# EPISODE 6 rew 1.0 True
# hit
# EPISODE 7 rew 1.6875 True
# EPISODE 8 rew 0.5625 True
# EPISODE 9 rew 0.3125 True
# EPISODE 10 rew 0.625 True
# EPISODE 11 rew 0.3125 True
# EPISODE 12 rew 1.3125 True
# EPISODE 13 rew 0.8125 True
# hit
# EPISODE 14 rew 1.875 True
# EPISODE 15 rew 0.6875 True
# EPISODE 16 rew 1.125 True
# EPISODE 17 rew 0.875 True
# EPISODE 18 rew 1.3125 True
# EPISODE 19 rew 0.3125 True
# hit
# EPISODE 20 rew 1.5 True
# EPISODE 21 rew 1.4375 True
# hit
# EPISODE 22 rew 1.5 True
# hit
# EPISODE 23 rew 1.4375 True
# EPISODE 24 rew 1.5625 True
# EPISODE 25 rew 0.3125 True
# EPISODE 26 rew 0.8125 True
# EPISODE 27 rew 0.375 True
# hit
# EPISODE 28 rew 1.5625 True
# hit
# EPISODE 29 rew 1.875 True
# EPISODE 30 rew 0.1875 True
# hit
# EPISODE 31 rew 1.625 True
# EPISODE 32 rew 0.75 True
# hit
# hit
# EPISODE 33 rew 2.25 True
# EPISODE 34 rew 0.5625 True
# EPISODE 35 rew 1.3125 True
# EPISODE 36 rew 0.5625 True
# hit
# hit
# hit
# EPISODE 37 rew 4.0 True
# hit
# EPISODE 38 rew 2.5625 True
# EPISODE 39 rew 0.5 True
# hit
# EPISODE 40 rew 1.625 True
# EPISODE 41 rew 0.5 True
# EPISODE 42 rew 0.9375 True
# hit
# EPISODE 43 rew 1.375 True
# EPISODE 44 rew 1.4375 True
# hit
# EPISODE 45 rew 1.6875 True
# hit
# hit
# hit
# EPISODE 46 rew 3.125 True
# EPISODE 47 rew 1.375 True
# EPISODE 48 rew 1.3125 True
# EPISODE 49 rew 0.5625 True
# EPISODE 50 rew 0.8125 True
# EPISODE 51 rew 2.875 True
# hit
# EPISODE 52 rew 2.3125 True
# EPISODE 53 rew 0.875 True
# hit
# EPISODE 54 rew 2.5 True
# EPISODE 55 rew 0.125 True
# hit
# EPISODE 56 rew 1.3125 True
# EPISODE 57 rew 0.5625 True
# hit
# EPISODE 58 rew 1.875 True
# EPISODE 59 rew 0.4375 True
# hit
# hit
# EPISODE 60 rew 2.25 True
# EPISODE 61 rew 0.5625 True
# hit
# EPISODE 62 rew 1.375 True
# hit
# hit
# EPISODE 63 rew 2.3125 True
# hit
# EPISODE 64 rew 2.25 True
# EPISODE 65 rew 0.5 True
# EPISODE 66 rew 0.5625 True
# hit
# EPISODE 67 rew 1.4375 True
# EPISODE 68 rew 0.875 True
# hit
# EPISODE 69 rew 2.0625 True
# hit
# EPISODE 70 rew 1.1875 True
# hit
# EPISODE 71 rew 1.875 True
# hit
# hit
# hit
# EPISODE 72 rew 3.5625 True
# EPISODE 73 rew 1.25 True
# hit
# EPISODE 74 rew 1.25 True
# hit
# EPISODE 75 rew 1.375 True
# hit
# EPISODE 76 rew 2.0625 True
# EPISODE 77 rew 0.4375 True
# hit
# EPISODE 78 rew 1.0625 True
# hit
# EPISODE 79 rew 1.125 True
# EPISODE 80 rew 0.125 True
# EPISODE 81 rew 0.875 True
# EPISODE 82 rew 1.8125 True
# hit
# EPISODE 83 rew 1.8125 True
# hit
# hit
# EPISODE 84 rew 3.0625 True
# hit
# EPISODE 85 rew 1.8125 True
# EPISODE 86 rew 0.8125 True
# hit
# EPISODE 87 rew 1.9375 True
# hit
# EPISODE 88 rew 1.75 True
# EPISODE 89 rew 0.4375 True
# EPISODE 90 rew 0.9375 True
# EPISODE 91 rew 2.375 True
# EPISODE 92 rew 0.5625 True
# hit
# EPISODE 93 rew 2.5625 True
# hit
# EPISODE 94 rew 1.9375 True
# hit
# hit
# EPISODE 95 rew 2.9375 True
# EPISODE 96 rew 0.25 True
# EPISODE 97 rew 1.25 True
# hit
# EPISODE 98 rew 1.4375 True
# hit
# EPISODE 99 rew 1.1875 True
# EPISODE 100 rew 1.8125 True
# EPISODE 101 rew 1.4375 True
# hit
# hit
# EPISODE 102 rew 3.0 True
# EPISODE 103 rew 1.0625 True
# EPISODE 104 rew 0.125 True
# EPISODE 105 rew 0.4375 True
# EPISODE 106 rew 1.3125 True
# EPISODE 107 rew 0.5 True
# hit
# EPISODE 108 rew 1.25 True
# EPISODE 109 rew 0.5 True
# EPISODE 110 rew 1.125 True
# EPISODE 111 rew 1.3125 True
# EPISODE 112 rew 0.625 True
# hit
# EPISODE 113 rew 1.5625 True
# hit
# hit
# EPISODE 114 rew 2.5625 True
# EPISODE 115 rew 1.1875 True
# EPISODE 116 rew 1.75 True
# hit
# EPISODE 117 rew 1.5625 True
# EPISODE 118 rew 0.8125 True
# EPISODE 119 rew 0.5625 True
# EPISODE 120 rew 0 True
# EPISODE 121 rew 0 True
# hit
# EPISODE 122 rew 1.875 True
# EPISODE 123 rew 2.8125 True
# EPISODE 124 rew 0.875 True
# hit
# EPISODE 125 rew 1.0625 True
# EPISODE 126 rew 1.0625 True
# hit
# hit
# EPISODE 127 rew 2.8125 True
# EPISODE 128 rew 1.0 True
# EPISODE 129 rew 1.4375 True
# EPISODE 130 rew 0.75 True
# EPISODE 131 rew 0.5 True
# EPISODE 132 rew 1.5 True
# hit
# EPISODE 133 rew 2.5625 True
# hit
# EPISODE 134 rew 1.3125 True
# EPISODE 135 rew 1.4375 True
# EPISODE 136 rew 1.0 True
# hit
# EPISODE 137 rew 1.9375 True
# EPISODE 138 rew 0 True
# hit
# hit
# EPISODE 139 rew 3.0 True
# EPISODE 140 rew 0.8125 True
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088470d048>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088470d048>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088470d048>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f088470d048>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085076ffd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085076ffd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085076ffd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085076ffd0>>: AttributeError: module 'gast' has no attribute 'Num'
# ESIMATION 2
# EPISODE 0 rew 0 True
# EPISODE 1 rew 0.625 True
# hit
# hit
# EPISODE 2 rew 2.75 True
# hit
# EPISODE 3 rew 1.125 True
# hit
# hit
# EPISODE 4 rew 2.9375 True
# hit
# EPISODE 5 rew 1.25 True
# hit
# EPISODE 6 rew 1.4375 True
# EPISODE 7 rew 0.625 True
# hit
# EPISODE 8 rew 1.1875 True
# EPISODE 9 rew 0.5 True
# hit
# EPISODE 10 rew 1.125 True
# EPISODE 11 rew 1.25 True
# hit
# EPISODE 12 rew 1.9375 True
# EPISODE 13 rew 0.6875 True
# hit
# EPISODE 14 rew 2.5625 True
# hit
# EPISODE 15 rew 1.375 True
# EPISODE 16 rew 0.3125 True
# EPISODE 17 rew 1.375 True
# hit
# EPISODE 18 rew 2.5 True
# EPISODE 19 rew 1.4375 True
# EPISODE 20 rew 1.0625 True
# hit
# EPISODE 21 rew 1.5 True
# EPISODE 22 rew 1.1875 True
# EPISODE 23 rew 0.5 True
# EPISODE 24 rew 1.3125 True
# EPISODE 25 rew 0.5 True
# hit
# EPISODE 26 rew 2.125 True
# hit
# EPISODE 27 rew 1.5625 True
# EPISODE 28 rew 0.875 True
# EPISODE 29 rew 0.8125 True
# EPISODE 30 rew 1.375 True
# hit
# EPISODE 31 rew 1.1875 True
# EPISODE 32 rew 0.0625 True
# hit
# EPISODE 33 rew 1.625 True
# EPISODE 34 rew 1.25 True
# EPISODE 35 rew 0.25 True
# EPISODE 36 rew 0.5 True
# EPISODE 37 rew 0.3125 True
# hit
# EPISODE 38 rew 2.25 True
# hit
# EPISODE 39 rew 2.0625 True
# hit
# hit
# EPISODE 40 rew 3.5 True
# hit
# EPISODE 41 rew 1.875 True
# EPISODE 42 rew 1.0 True
# EPISODE 43 rew 1.3125 True
# EPISODE 44 rew 0.1875 True
# EPISODE 45 rew 1.0625 True
# hit
# EPISODE 46 rew 1.5625 True
# EPISODE 47 rew 0.3125 True
# EPISODE 48 rew 0.4375 True
# EPISODE 49 rew 1.1875 True
# EPISODE 50 rew 1.5625 True
# EPISODE 51 rew 0.4375 True
# EPISODE 52 rew 1.6875 True
# hit
# EPISODE 53 rew 1.875 True
# EPISODE 54 rew 1.5 True
# EPISODE 55 rew 1.875 True
# hit
# EPISODE 56 rew 1.875 True
# EPISODE 57 rew 0.625 True
# hit
# EPISODE 58 rew 1.5625 True
# EPISODE 59 rew 1.0 True
# hit
# EPISODE 60 rew 1.8125 True
# hit
# EPISODE 61 rew 1.625 True
# EPISODE 62 rew 1.125 True
# EPISODE 63 rew 0 True
# EPISODE 64 rew 1.0 True
# EPISODE 65 rew 1.625 True
# hit
# EPISODE 66 rew 1.875 True
# EPISODE 67 rew 0.75 True
# EPISODE 68 rew 0.5625 True
# EPISODE 69 rew 0.875 True
# hit
# hit
# EPISODE 70 rew 2.5625 True
# hit
# EPISODE 71 rew 1.3125 True
# EPISODE 72 rew 0.375 True
# hit
# hit
# EPISODE 73 rew 3.1875 True
# hit
# EPISODE 74 rew 1.6875 True
# hit
# EPISODE 75 rew 1.6875 True
# EPISODE 76 rew 1.125 True
# EPISODE 77 rew 2.0625 True
# EPISODE 78 rew 0 True
# EPISODE 79 rew 1.9375 True
# EPISODE 80 rew 0.4375 True
# EPISODE 81 rew 1.625 True
# EPISODE 82 rew 0.75 True
# hit
# EPISODE 83 rew 2.25 True
# hit
# EPISODE 84 rew 1.375 True
# EPISODE 85 rew 0.875 True
# EPISODE 86 rew 0.4375 True
# EPISODE 87 rew 1.375 True
# hit
# EPISODE 88 rew 1.375 True
# hit
# EPISODE 89 rew 2.375 True
# EPISODE 90 rew 0.5625 True
# EPISODE 91 rew 0.5 True
# EPISODE 92 rew 0.4375 True
# hit
# EPISODE 93 rew 1.9375 True
# EPISODE 94 rew 0.75 True
# EPISODE 95 rew 0.4375 True
# EPISODE 96 rew 0.5625 True
# hit
# EPISODE 97 rew 2.125 True
# EPISODE 98 rew 0.125 True
# EPISODE 99 rew 0.1875 True
# hit
# EPISODE 100 rew 1.8125 True
# hit
# EPISODE 101 rew 1.5625 True
# hit
# EPISODE 102 rew 1.5625 True
# EPISODE 103 rew 1.0 True
# EPISODE 104 rew 1.1875 True
# EPISODE 105 rew 1.5 True
# EPISODE 106 rew 0.5625 True
# hit
# EPISODE 107 rew 1.6875 True
# EPISODE 108 rew 0.6875 True
# EPISODE 109 rew 1.5625 True
# EPISODE 110 rew 0.9375 True
# hit
# EPISODE 111 rew 1.8125 True
# EPISODE 112 rew 2.0 True
# EPISODE 113 rew 0.75 True
# EPISODE 114 rew 0.5 True
# EPISODE 115 rew 0.9375 True
# hit
# EPISODE 116 rew 1.5 True
# hit
# EPISODE 117 rew 1.875 True
# hit
# EPISODE 118 rew 2.1875 True
# EPISODE 119 rew 0.5 True
# EPISODE 120 rew 1.5 True
# EPISODE 121 rew 0.3125 True
# hit
# EPISODE 122 rew 1.1875 True
# EPISODE 123 rew 0.5625 True
# hit
# EPISODE 124 rew 1.375 True
# EPISODE 125 rew 0.8125 True
# EPISODE 126 rew 0.5 True
# hit
# EPISODE 127 rew 1.3125 True
# hit
# EPISODE 128 rew 1.625 True
# EPISODE 129 rew 1.25 True
# EPISODE 130 rew 0.3125 True
# hit
# EPISODE 131 rew 2.0625 True
# EPISODE 132 rew 1.0625 True
# EPISODE 133 rew 1.1875 True
# EPISODE 134 rew 0.75 True
# EPISODE 135 rew 0.25 True
# EPISODE 136 rew 0.3125 True
# hit
# EPISODE 137 rew 3.0 True
# EPISODE 138 rew 0.5 True
# hit
# EPISODE 139 rew 2.0625 True
# hit
# hit
# EPISODE 140 rew 2.625 True
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f5f8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f5f8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f5f8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f5f8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f400>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f085054f400>>: AttributeError: module 'gast' has no attribute 'Num'
# ESIMATION 3
# EPISODE 0 rew 0.375 True
# EPISODE 1 rew 1.5 True
# EPISODE 2 rew 1.625 True
# hit
# EPISODE 3 rew 1.75 True
# EPISODE 4 rew 1.375 True
# hit
# EPISODE 5 rew 2.3125 True
# EPISODE 6 rew 0.375 True
# EPISODE 7 rew 0.375 True
# EPISODE 8 rew 0.375 True
# hit
# hit
# EPISODE 9 rew 3.4375 True
# hit
# hit
# EPISODE 10 rew 2.125 True
# hit
# EPISODE 11 rew 2.25 True
# hit
# hit
# EPISODE 12 rew 3.375 True
# EPISODE 13 rew 0.8125 True
# EPISODE 14 rew 0.6875 True
# EPISODE 15 rew 0.125 True
# EPISODE 16 rew 0.6875 True
# EPISODE 17 rew 0.625 True
# hit
# EPISODE 18 rew 1.5 True
# EPISODE 19 rew 0.8125 True
# EPISODE 20 rew 0.8125 True
# EPISODE 21 rew 0.5625 True
# hit
# EPISODE 22 rew 1.3125 True
# EPISODE 23 rew 1.25 True
# EPISODE 24 rew 0 True
# EPISODE 25 rew 0.5625 True
# hit
# EPISODE 26 rew 1.5625 True
# EPISODE 27 rew 1.4375 True
# hit
# EPISODE 28 rew 1.3125 True
# EPISODE 29 rew 0.6875 True
# hit
# EPISODE 30 rew 2.25 True
# EPISODE 31 rew 0.8125 True
# EPISODE 32 rew 1.0 True
# EPISODE 33 rew 0.875 True
# hit
# EPISODE 34 rew 1.625 True
# EPISODE 35 rew 0 True
# EPISODE 36 rew 1.125 True
# EPISODE 37 rew 0.5 True
# hit
# hit
# EPISODE 38 rew 2.4375 True
# EPISODE 39 rew 0.25 True
# EPISODE 40 rew 0.0625 True
# hit
# EPISODE 41 rew 1.125 True
# EPISODE 42 rew 0.9375 True
# EPISODE 43 rew 0.875 True
# EPISODE 44 rew 0.5625 True
# EPISODE 45 rew 1.0625 True
# hit
# EPISODE 46 rew 2.0 True
# EPISODE 47 rew 0.4375 True
# EPISODE 48 rew 1.5 True
# hit
# EPISODE 49 rew 1.25 True
# EPISODE 50 rew 1.0 True
# hit
# EPISODE 51 rew 1.125 True
# EPISODE 52 rew 0.75 True
# EPISODE 53 rew 0.5 True
# EPISODE 54 rew 0.75 True
# EPISODE 55 rew 0.9375 True
# hit
# EPISODE 56 rew 1.6875 True
# EPISODE 57 rew 1.25 True
# EPISODE 58 rew 0.1875 True
# EPISODE 59 rew 1.4375 True
# EPISODE 60 rew 0.5 True
# hit
# EPISODE 61 rew 1.3125 True
# EPISODE 62 rew 1.125 True
# hit
# EPISODE 63 rew 1.25 True
# hit
# EPISODE 64 rew 2.0 True
# EPISODE 65 rew 0.4375 True
# EPISODE 66 rew 0.5 True
# EPISODE 67 rew 1.6875 True
# hit
# EPISODE 68 rew 1.75 True
# hit
# EPISODE 69 rew 1.4375 True
# EPISODE 70 rew 0.5 True
# EPISODE 71 rew 1.125 True
# EPISODE 72 rew 0.9375 True
# EPISODE 73 rew 0.9375 True
# hit
# EPISODE 74 rew 1.125 True
# EPISODE 75 rew 0.5625 True
# EPISODE 76 rew 0.875 True
# hit
# EPISODE 77 rew 2.75 True
# hit
# EPISODE 78 rew 2.75 True
# hit
# EPISODE 79 rew 1.25 True
# hit
# hit
# EPISODE 80 rew 2.25 True
# EPISODE 81 rew 1.375 True
# hit
# EPISODE 82 rew 1.5 True
# hit
# hit
# EPISODE 83 rew 2.4375 True
# EPISODE 84 rew 1.125 True
# hit
# EPISODE 85 rew 2.125 True
# hit
# EPISODE 86 rew 1.125 True
# hit
# EPISODE 87 rew 1.125 True
# EPISODE 88 rew 0.375 True
# EPISODE 89 rew 0.0625 True
# hit
# EPISODE 90 rew 1.375 True
# EPISODE 91 rew 0.875 True
# EPISODE 92 rew 1.125 True
# EPISODE 93 rew 0.9375 True
# EPISODE 94 rew 0.625 True
# EPISODE 95 rew 1.875 True
# hit
# hit
# EPISODE 96 rew 3.5 True
# hit
# EPISODE 97 rew 1.375 True
# hit
# EPISODE 98 rew 2.1875 True
# hit
# EPISODE 99 rew 2.3125 True
# EPISODE 100 rew 0.875 True
# EPISODE 101 rew 0.375 True
# EPISODE 102 rew 0.625 True
# EPISODE 103 rew 1.0625 True
# hit
# EPISODE 104 rew 1.5 True
# EPISODE 105 rew 1.5625 True
# EPISODE 106 rew 1.375 True
# EPISODE 107 rew 0.0625 True
# EPISODE 108 rew 2.375 True
# EPISODE 109 rew 0.75 True
# EPISODE 110 rew 0.5625 True
# EPISODE 111 rew 0.5 True
# EPISODE 112 rew 1.1875 True
# hit
# EPISODE 113 rew 2.625 True
# EPISODE 114 rew 0.375 True
# hit
# hit
# EPISODE 115 rew 2.1875 True
# hit
# EPISODE 116 rew 1.4375 True
# EPISODE 117 rew 0.625 True
# EPISODE 118 rew 0.0625 True
# hit
# EPISODE 119 rew 1.5625 True
# hit
# hit
# EPISODE 120 rew 2.8125 True
# hit
# hit
# EPISODE 121 rew 2.5 True
# EPISODE 122 rew 0.875 True
# hit
# hit
# hit
# hit
# EPISODE 123 rew 4.375 True
# hit
# EPISODE 124 rew 2.125 True
# hit
# EPISODE 125 rew 1.375 True
# EPISODE 126 rew 1.125 True
# EPISODE 127 rew 0 True
# EPISODE 128 rew 0.25 True
# EPISODE 129 rew 0.8125 True
# hit
# EPISODE 130 rew 2.375 True
# EPISODE 131 rew 0.1875 True
# hit
# hit
# EPISODE 132 rew 2.8125 True
# hit
# EPISODE 133 rew 2.0 True
# hit
# EPISODE 134 rew 2.25 True
# hit
# EPISODE 135 rew 2.0625 True
# EPISODE 136 rew 0.375 True
# hit
# EPISODE 137 rew 1.75 True
# EPISODE 138 rew 0.9375 True
# hit
# hit
# EPISODE 139 rew 2.8125 True
# hit
# EPISODE 140 rew 3.75 True
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c827fa90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c827fa90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c827fa90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08c827fa90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08902af978>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08902af978>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08902af978>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08902af978>>: AttributeError: module 'gast' has no attribute 'Num'
# ESIMATION 4
# hit
# EPISODE 0 rew 1.75 True
# EPISODE 1 rew 2.125 True
# EPISODE 2 rew 1.1875 True
# hit
# EPISODE 3 rew 2.375 True
# hit
# EPISODE 4 rew 2.6875 True
# EPISODE 5 rew 0.8125 True
# EPISODE 6 rew 0.625 True
# EPISODE 7 rew 2.0625 True
# EPISODE 8 rew 0.5 True
# hit
# EPISODE 9 rew 3.25 True
# EPISODE 10 rew 2.375 True
# EPISODE 11 rew 0.3125 True
# EPISODE 12 rew 1.125 True
# hit
# EPISODE 13 rew 2.5 True
# hit
# EPISODE 14 rew 1.4375 True
# EPISODE 15 rew 0.4375 True
# EPISODE 16 rew 0.5 True
# EPISODE 17 rew 0.4375 True
# EPISODE 18 rew 0.875 True
# EPISODE 19 rew 0.5625 True
# hit
# hit
# EPISODE 20 rew 3.1875 True
# EPISODE 21 rew 0.75 True
# EPISODE 22 rew 1.4375 True
# EPISODE 23 rew 0.125 True
# EPISODE 24 rew 0.125 True
# EPISODE 25 rew 0.4375 True
# hit
# EPISODE 26 rew 2.0625 True
# EPISODE 27 rew 1.4375 True
# EPISODE 28 rew 1.125 True
# EPISODE 29 rew 0.6875 True
# EPISODE 30 rew 0.6875 True
# EPISODE 31 rew 0.8125 True
# EPISODE 32 rew 1.3125 True
# EPISODE 33 rew 1.125 True
# EPISODE 34 rew 0.375 True
# EPISODE 35 rew 0.3125 True
# hit
# hit
# EPISODE 36 rew 3.0625 True
# hit
# EPISODE 37 rew 1.6875 True
# hit
# EPISODE 38 rew 2.5 True
# EPISODE 39 rew 0.5 True
# hit
# EPISODE 40 rew 2.0625 True
# hit
# EPISODE 41 rew 2.25 True
# EPISODE 42 rew 0.3125 True
# EPISODE 43 rew 1.0625 True
# EPISODE 44 rew 0.125 True
# EPISODE 45 rew 0.75 True
# hit
# EPISODE 46 rew 1.1875 True
# EPISODE 47 rew 1.25 True
# hit
# EPISODE 48 rew 2.0 True
# hit
# EPISODE 49 rew 1.4375 True
# EPISODE 50 rew 0.6875 True
# EPISODE 51 rew 1.625 True
# hit
# EPISODE 52 rew 1.8125 True
# EPISODE 53 rew 1.1875 True
# hit
# EPISODE 54 rew 1.625 True
# EPISODE 55 rew 0.25 True
# EPISODE 56 rew 1.6875 True
# EPISODE 57 rew 0.625 True
# EPISODE 58 rew 0.375 True
# EPISODE 59 rew 1.1875 True
# EPISODE 60 rew 1.125 True
# hit
# EPISODE 61 rew 1.75 True
# EPISODE 62 rew 0.5 True
# EPISODE 63 rew 1.25 True
# EPISODE 64 rew 0.4375 True
# EPISODE 65 rew 0.6875 True
# hit
# EPISODE 66 rew 1.125 True
# hit
# EPISODE 67 rew 1.4375 True
# EPISODE 68 rew 0.6875 True
# hit
# EPISODE 69 rew 1.5625 True
# EPISODE 70 rew 0 True
# EPISODE 71 rew 0.875 True
# EPISODE 72 rew 1.25 True
# hit
# EPISODE 73 rew 1.25 True
# EPISODE 74 rew 0.0625 True
# hit
# EPISODE 75 rew 2.125 True
# EPISODE 76 rew 0.0625 True
# EPISODE 77 rew 1.3125 True
# hit
# EPISODE 78 rew 1.3125 True
# hit
# EPISODE 79 rew 1.5 True
# hit
# hit
# EPISODE 80 rew 2.6875 True
# EPISODE 81 rew 0.75 True
# hit
# EPISODE 82 rew 1.6875 True
# hit
# EPISODE 83 rew 1.6875 True
# EPISODE 84 rew 0.3125 True
# EPISODE 85 rew 1.25 True
# hit
# hit
# EPISODE 86 rew 2.125 True
# hit
# EPISODE 87 rew 1.5625 True
# EPISODE 88 rew 1.25 True
# hit
# EPISODE 89 rew 1.5 True
# hit
# EPISODE 90 rew 1.4375 True
# EPISODE 91 rew 0.875 True
# EPISODE 92 rew 1.0 True
# EPISODE 93 rew 0.125 True
# EPISODE 94 rew 0.3125 True
# hit
# EPISODE 95 rew 1.4375 True
# hit
# EPISODE 96 rew 2.75 True
# EPISODE 97 rew 1.75 True
# hit
# EPISODE 98 rew 1.1875 True
# EPISODE 99 rew 1.375 True
# hit
# hit
# EPISODE 100 rew 2.4375 True
# EPISODE 101 rew 1.1875 True
# hit
# EPISODE 102 rew 2.0625 True
# EPISODE 103 rew 1.4375 True
# EPISODE 104 rew 0.3125 True
# hit
# EPISODE 105 rew 1.4375 True
# EPISODE 106 rew 0.8125 True
# EPISODE 107 rew 0.125 True
# hit
# hit
# EPISODE 108 rew 3.3125 True
# hit
# EPISODE 109 rew 2.0625 True
# hit
# hit
# EPISODE 110 rew 2.5625 True
# EPISODE 111 rew 1.0625 True
# EPISODE 112 rew 1.5 True
# EPISODE 113 rew 0.1875 True
# EPISODE 114 rew 1.125 True
# hit
# EPISODE 115 rew 1.0625 True
# EPISODE 116 rew 0 True
# hit
# EPISODE 117 rew 1.6875 True
# EPISODE 118 rew 0 True
# hit
# hit
# EPISODE 119 rew 2.6875 True
# EPISODE 120 rew 0.4375 True
# EPISODE 121 rew 0.9375 True
# EPISODE 122 rew 0 True
# hit
# EPISODE 123 rew 2.5625 True
# hit
# EPISODE 124 rew 1.4375 True
# hit
# EPISODE 125 rew 2.0625 True
# EPISODE 126 rew 0.625 True
# EPISODE 127 rew 0.4375 True
# EPISODE 128 rew 0.875 True
# hit
# EPISODE 129 rew 1.3125 True
# EPISODE 130 rew 0.5625 True
# hit
# EPISODE 131 rew 2.5625 True
# EPISODE 132 rew 0.1875 True
# hit
# EPISODE 133 rew 1.6875 True
# hit
# EPISODE 134 rew 2.0625 True
# EPISODE 135 rew 1.375 True
# EPISODE 136 rew 1.1875 True
# EPISODE 137 rew 0.5625 True
# hit
# EPISODE 138 rew 1.6875 True
# hit
# EPISODE 139 rew 1.75 True
# EPISODE 140 rew 0.375 True

# %%
plt.plot(rew_episodes)

# %%
np.mean(rew_episodes)
# Out:
# 1.236258865248227

# %%
report
# Out:
# [1.2686170212765957,
#  1.3249113475177305,
#  1.2349290780141844,
#  1.2770390070921986,
#  1.236258865248227]
