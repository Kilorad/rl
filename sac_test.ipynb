# %%
import gym
import numpy as np

from stable_baselines.sac.policies import MlpPolicy
from stable_baselines import SAC

env = gym.make('Pendulum-v0')

model = SAC(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=50000, log_interval=10)
model.save("sac_pendulum")

del model # remove to demonstrate saving and loading

model = SAC.load("sac_pendulum")

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
# Out:
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:58: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/sac.py:155: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py:212: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f4974dd1828>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f4974dd1828>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f4974dd1828>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f4974dd1828>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py:49: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/s.dovgan/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4974dd1e48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4974dd1e48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4974dd1e48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4974dd1e48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f498611c160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f498611c160>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f498611c160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f498611c160>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4984c43e48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py:234: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d87f0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972818ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972818ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972818ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972818ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972893cc0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972893cc0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972893cc0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972893cc0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49728d8f98>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f497287d6a0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f497287d6a0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f497287d6a0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f497287d6a0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811f60>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f4972811198>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f49727af9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f49728a5cf8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286be48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286bb00>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286bb00>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286bb00>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f497286bb00>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/sac.py:246: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/s.dovgan/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/sac.py:309: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/sac.py:329: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.60613    |
# | ent_coef_loss           | -0.8250679 |
# | entropy                 | 1.1461959  |
# | episodes                | 10         |
# | fps                     | 167        |
# | mean 100 episode reward | -1.46e+03  |
# | n_updates               | 1700       |
# | policy_loss             | 51.96716   |
# | qf1_loss                | 0.5422036  |
# | qf2_loss                | 0.48273182 |
# | time_elapsed            | 10         |
# | total timesteps         | 1800       |
# | value_loss              | 0.26270658 |
# ----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.38064766  |
# | ent_coef_loss           | -0.64440346 |
# | entropy                 | 0.8273287   |
# | episodes                | 20          |
# | fps                     | 168         |
# | mean 100 episode reward | -1.27e+03   |
# | n_updates               | 3700        |
# | policy_loss             | 97.27733    |
# | qf1_loss                | 3.0980124   |
# | qf2_loss                | 3.307946    |
# | time_elapsed            | 22          |
# | total timesteps         | 3800        |
# | value_loss              | 0.32727492  |
# -----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.2657132  |
# | ent_coef_loss           | -0.4384604 |
# | entropy                 | 0.720933   |
# | episodes                | 30         |
# | fps                     | 168        |
# | mean 100 episode reward | -1.3e+03   |
# | n_updates               | 5700       |
# | policy_loss             | 110.36494  |
# | qf1_loss                | 5.921718   |
# | qf2_loss                | 4.5903115  |
# | time_elapsed            | 34         |
# | total timesteps         | 5800       |
# | value_loss              | 0.9733503  |
# ----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.18337145 |
# | ent_coef_loss           | -0.7205123 |
# | entropy                 | 0.550102   |
# | episodes                | 40         |
# | fps                     | 171        |
# | mean 100 episode reward | -1.26e+03  |
# | n_updates               | 7700       |
# | policy_loss             | 144.64853  |
# | qf1_loss                | 4.8305893  |
# | qf2_loss                | 5.0386744  |
# | time_elapsed            | 45         |
# | total timesteps         | 7800       |
# | value_loss              | 0.7069695  |
# ----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.15097791  |
# | ent_coef_loss           | -0.13195172 |
# | entropy                 | 0.4753218   |
# | episodes                | 50          |
# | fps                     | 172         |
# | mean 100 episode reward | -1.15e+03   |
# | n_updates               | 9700        |
# | policy_loss             | 181.8062    |
# | qf1_loss                | 292.906     |
# | qf2_loss                | 297.84967   |
# | time_elapsed            | 56          |
# | total timesteps         | 9800        |
# | value_loss              | 1.4882818   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.1245195   |
# | ent_coef_loss           | 0.083352216 |
# | entropy                 | 0.3613751   |
# | episodes                | 60          |
# | fps                     | 172         |
# | mean 100 episode reward | -1.09e+03   |
# | n_updates               | 11700       |
# | policy_loss             | 206.49289   |
# | qf1_loss                | 4.5593667   |
# | qf2_loss                | 3.6364877   |
# | time_elapsed            | 68          |
# | total timesteps         | 11800       |
# | value_loss              | 0.9358939   |
# -----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.0930626  |
# | ent_coef_loss           | 0.42752907 |
# | entropy                 | 0.0955594  |
# | episodes                | 70         |
# | fps                     | 172        |
# | mean 100 episode reward | -1.03e+03  |
# | n_updates               | 13700      |
# | policy_loss             | 207.87257  |
# | qf1_loss                | 359.43613  |
# | qf2_loss                | 351.76767  |
# | time_elapsed            | 79         |
# | total timesteps         | 13800      |
# | value_loss              | 1.7123355  |
# ----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.11655793 |
# | ent_coef_loss           | 0.06958485 |
# | entropy                 | 0.26492482 |
# | episodes                | 80         |
# | fps                     | 173        |
# | mean 100 episode reward | -967       |
# | n_updates               | 15700      |
# | policy_loss             | 208.55197  |
# | qf1_loss                | 7.5723515  |
# | qf2_loss                | 5.6132007  |
# | time_elapsed            | 91         |
# | total timesteps         | 15800      |
# | value_loss              | 0.7482059  |
# ----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.15680021 |
# | ent_coef_loss           | 0.1578394  |
# | entropy                 | 0.16273268 |
# | episodes                | 90         |
# | fps                     | 171        |
# | mean 100 episode reward | -885       |
# | n_updates               | 17700      |
# | policy_loss             | 210.81964  |
# | qf1_loss                | 7.2783184  |
# | qf2_loss                | 5.132943   |
# | time_elapsed            | 104        |
# | total timesteps         | 17800      |
# | value_loss              | 0.7862984  |
# ----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.19659457  |
# | ent_coef_loss           | -0.19157195 |
# | entropy                 | 0.076698914 |
# | episodes                | 100         |
# | fps                     | 169         |
# | mean 100 episode reward | -815        |
# | n_updates               | 19700       |
# | policy_loss             | 210.88239   |
# | qf1_loss                | 913.416     |
# | qf2_loss                | 916.22754   |
# | time_elapsed            | 116         |
# | total timesteps         | 19800       |
# | value_loss              | 0.7701019   |
# -----------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.21404523   |
# | ent_coef_loss           | 0.072310805  |
# | entropy                 | -0.008285146 |
# | episodes                | 110          |
# | fps                     | 166          |
# | mean 100 episode reward | -696         |
# | n_updates               | 21700        |
# | policy_loss             | 202.44562    |
# | qf1_loss                | 4.45726      |
# | qf2_loss                | 3.602685     |
# | time_elapsed            | 130          |
# | total timesteps         | 21800        |
# | value_loss              | 0.4857782    |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.23983848   |
# | ent_coef_loss           | -0.052653726 |
# | entropy                 | 0.054238487  |
# | episodes                | 120          |
# | fps                     | 163          |
# | mean 100 episode reward | -606         |
# | n_updates               | 23700        |
# | policy_loss             | 213.20273    |
# | qf1_loss                | 6.0670247    |
# | qf2_loss                | 5.755727     |
# | time_elapsed            | 145          |
# | total timesteps         | 23800        |
# | value_loss              | 0.80520374   |
# ------------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.2568477   |
# | ent_coef_loss           | 0.121771045 |
# | entropy                 | 0.048018888 |
# | episodes                | 130         |
# | fps                     | 161         |
# | mean 100 episode reward | -490        |
# | n_updates               | 25700       |
# | policy_loss             | 196.04904   |
# | qf1_loss                | 5.19228     |
# | qf2_loss                | 5.3485117   |
# | time_elapsed            | 159         |
# | total timesteps         | 25800       |
# | value_loss              | 1.3792603   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.29799163  |
# | ent_coef_loss           | 0.15610482  |
# | entropy                 | -0.08653727 |
# | episodes                | 140         |
# | fps                     | 159         |
# | mean 100 episode reward | -400        |
# | n_updates               | 27700       |
# | policy_loss             | 178.28323   |
# | qf1_loss                | 4.3145485   |
# | qf2_loss                | 6.1727324   |
# | time_elapsed            | 174         |
# | total timesteps         | 27800       |
# | value_loss              | 1.0724903   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.33430567  |
# | ent_coef_loss           | 0.19754207  |
# | entropy                 | -0.07949013 |
# | episodes                | 150         |
# | fps                     | 159         |
# | mean 100 episode reward | -347        |
# | n_updates               | 29700       |
# | policy_loss             | 170.87578   |
# | qf1_loss                | 6.4376855   |
# | qf2_loss                | 9.371584    |
# | time_elapsed            | 187         |
# | total timesteps         | 29800       |
# | value_loss              | 1.2971966   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.3383594   |
# | ent_coef_loss           | 0.114891976 |
# | entropy                 | 0.012003094 |
# | episodes                | 160         |
# | fps                     | 159         |
# | mean 100 episode reward | -281        |
# | n_updates               | 31700       |
# | policy_loss             | 161.6232    |
# | qf1_loss                | 1153.5088   |
# | qf2_loss                | 1162.3181   |
# | time_elapsed            | 198         |
# | total timesteps         | 31800       |
# | value_loss              | 1.6250772   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.32716563  |
# | ent_coef_loss           | -0.10968475 |
# | entropy                 | 0.16917014  |
# | episodes                | 170         |
# | fps                     | 160         |
# | mean 100 episode reward | -228        |
# | n_updates               | 33700       |
# | policy_loss             | 149.75745   |
# | qf1_loss                | 7.3117337   |
# | qf2_loss                | 6.6244173   |
# | time_elapsed            | 210         |
# | total timesteps         | 33800       |
# | value_loss              | 1.704274    |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.26969245  |
# | ent_coef_loss           | -0.18746886 |
# | entropy                 | 0.053972043 |
# | episodes                | 180         |
# | fps                     | 161         |
# | mean 100 episode reward | -188        |
# | n_updates               | 35700       |
# | policy_loss             | 122.03145   |
# | qf1_loss                | 2.0725741   |
# | qf2_loss                | 1.822856    |
# | time_elapsed            | 221         |
# | total timesteps         | 35800       |
# | value_loss              | 1.2751946   |
# -----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.26414052 |
# | ent_coef_loss           | 0.2557332  |
# | entropy                 | 0.05256849 |
# | episodes                | 190        |
# | fps                     | 162        |
# | mean 100 episode reward | -184       |
# | n_updates               | 37700      |
# | policy_loss             | 124.48191  |
# | qf1_loss                | 6.1355553  |
# | qf2_loss                | 5.65944    |
# | time_elapsed            | 233        |
# | total timesteps         | 37800      |
# | value_loss              | 0.96646667 |
# ----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.2606864   |
# | ent_coef_loss           | 0.047402743 |
# | entropy                 | 0.034153003 |
# | episodes                | 200         |
# | fps                     | 162         |
# | mean 100 episode reward | -179        |
# | n_updates               | 39700       |
# | policy_loss             | 107.36034   |
# | qf1_loss                | 4.757821    |
# | qf2_loss                | 3.8628163   |
# | time_elapsed            | 244         |
# | total timesteps         | 39800       |
# | value_loss              | 0.9455173   |
# -----------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.25057197   |
# | ent_coef_loss           | -0.33194885  |
# | entropy                 | -0.114634745 |
# | episodes                | 210          |
# | fps                     | 163          |
# | mean 100 episode reward | -173         |
# | n_updates               | 41700        |
# | policy_loss             | 84.15065     |
# | qf1_loss                | 2.1679678    |
# | qf2_loss                | 2.9777722    |
# | time_elapsed            | 255          |
# | total timesteps         | 41800        |
# | value_loss              | 1.9037774    |
# ------------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.24406251  |
# | ent_coef_loss           | 0.102910444 |
# | entropy                 | -0.04640865 |
# | episodes                | 220         |
# | fps                     | 163         |
# | mean 100 episode reward | -165        |
# | n_updates               | 43700       |
# | policy_loss             | 98.58794    |
# | qf1_loss                | 12.174431   |
# | qf2_loss                | 5.4270325   |
# | time_elapsed            | 267         |
# | total timesteps         | 43800       |
# | value_loss              | 3.000145    |
# -----------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.2396676    |
# | ent_coef_loss           | -0.059857197 |
# | entropy                 | -0.15992221  |
# | episodes                | 230          |
# | fps                     | 164          |
# | mean 100 episode reward | -159         |
# | n_updates               | 45700        |
# | policy_loss             | 70.210785    |
# | qf1_loss                | 2.623533     |
# | qf2_loss                | 3.3663158    |
# | time_elapsed            | 279          |
# | total timesteps         | 45800        |
# | value_loss              | 0.90941924   |
# ------------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.23388582  |
# | ent_coef_loss           | 0.3541053   |
# | entropy                 | -0.20262563 |
# | episodes                | 240         |
# | fps                     | 164         |
# | mean 100 episode reward | -151        |
# | n_updates               | 47700       |
# | policy_loss             | 77.03444    |
# | qf1_loss                | 14.369612   |
# | qf2_loss                | 15.153569   |
# | time_elapsed            | 290         |
# | total timesteps         | 47800       |
# | value_loss              | 2.0784502   |
# -----------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.2466114    |
# | ent_coef_loss           | 0.069723934  |
# | entropy                 | -0.048143283 |
# | episodes                | 250          |
# | fps                     | 164          |
# | mean 100 episode reward | -143         |
# | n_updates               | 49700        |
# | policy_loss             | 81.236176    |
# | qf1_loss                | 372.42813    |
# | qf2_loss                | 367.82315    |
# | time_elapsed            | 302          |
# | total timesteps         | 49800        |
# | value_loss              | 1.4007382    |
# ------------------------------------------
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac23fac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac23fac8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac23fac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac23fac8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac23fe10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac23fe10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac23fe10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac23fe10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# ...
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d46127b8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d46127b8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d46127b8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d46127b8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d4612710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d4612710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d4612710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48d4612710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac2d63c8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac2d63c8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac2d63c8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f48ac2d63c8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac384048>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac384048>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac384048>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f48ac384048>>: AssertionError: Bad argument number for Name: 3, expecting 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8c0578311c5a> in <module>()
#      13 del model # remove to demonstrate saving and loading
#      14
# ---> 15 model = SAC.load("sac_pendulum")
#      16
#      17 obs = env.reset()
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/common/base_class.py in load(cls, load_path, env, custom_objects, **kwargs)
#     967         model.__dict__.update(kwargs)
#     968         model.set_env(env)
# --> 969         model.setup_model()
#     970
#     971         model.load_parameters(params)
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/sac.py in setup_model(self)
#     187                     qf1_pi, qf2_pi, _ = self.policy_tf.make_critics(self.processed_obs_ph,
#     188                                                                     policy_out, create_qf=True, create_vf=False,
# --> 189                                                                     reuse=True)
#     190
#     191                     # Target entropy is used when learning the entropy coefficient
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py in make_critics(self, obs, action, reuse, scope, create_vf, create_qf)
#     267                 # Double Q values to reduce overestimation
#     268                 with tf.variable_scope('qf1', reuse=reuse):
# --> 269                     qf1_h = mlp(qf_h, self.layers, self.activ_fn, layer_norm=self.layer_norm)
#     270                     qf1 = tf.layers.dense(qf1_h, 1, name="qf1")
#     271
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py in mlp(input_ph, layers, activ_fn, layer_norm)
#      47     output = input_ph
#      48     for i, layer_size in enumerate(layers):
# ---> 49         output = tf.layers.dense(output, layer_size, name='fc' + str(i))
#      50         if layer_norm:
#      51             output = tf.contrib.layers.layer_norm(output, center=True, scale=True)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/layers/core.py in dense(inputs, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, trainable, name, reuse)
#     186                 _scope=name,
#     187                 _reuse=reuse)
# --> 188   return layer.apply(inputs)
#     189
#     190
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in apply(self, inputs, *args, **kwargs)
#    1477       Output tensor(s).
#    1478     """
# -> 1479     return self.__call__(inputs, *args, **kwargs)
#    1480
#    1481   @doc_controls.for_subclass_implementers
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     535
#     536       # Actually call layer
# --> 537       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     538
#     539     if not context.executing_eagerly():
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     632                     outputs = base_layer_utils.mark_as_return(outputs, acd)
#     633                 else:
# --> 634                   outputs = call_fn(inputs, *args, **kwargs)
#     635
#     636             except TypeError as e:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     144                 force_conversion=True,
#     145                 optional_features=optional_features,
# --> 146             ), args, kwargs)
#     147       except Exception as e:  # pylint:disable=broad-except
#     148         if hasattr(e, 'ag_error_metadata'):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, owner, options, args, kwargs)
#     421         target_entity,
#     422         recursive=options.recursive,
# --> 423         experimental_optional_features=options.optional_features)
#     424
#     425     if logging.has_verbosity(2):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in to_graph(entity, recursive, experimental_optional_features)
#     522             optional_features=experimental_optional_features),
#     523         autograph_module=tf_inspect.getmodule(to_graph))
# --> 524     return conversion.convert(entity, program_ctx)
#     525   except (ValueError, AttributeError, KeyError, NameError, AssertionError) as e:
#     526     logging.error(1, 'Error converting %s', entity, exc_info=True)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/conversion.py in convert(entity, program_ctx)
#     304
#     305   converted_entity_info = _convert_with_cache(
# --> 306       entity, program_ctx, free_nonglobal_var_names)
#     307
#     308   return _instantiate(entity, converted_entity_info, free_nonglobal_var_names)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/conversion.py in _convert_with_cache(entity, program_ctx, free_nonglobal_var_names)
#     227
#     228   nodes, converted_name, entity_info = convert_entity_to_ast(
# --> 229       entity, program_ctx)
#     230
#     231   namer = naming.Namer(entity_info.namespace)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/conversion.py in convert_entity_to_ast(o, program_ctx)
#     431     nodes, name, entity_info = convert_func_to_ast(o, program_ctx)
#     432   elif tf_inspect.ismethod(o):
# --> 433     nodes, name, entity_info = convert_func_to_ast(o, program_ctx)
#     434   elif hasattr(o, '__class__'):
#     435     # Note: this should only be raised when attempting to convert the object
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/conversion.py in convert_func_to_ast(f, program_ctx, do_rename)
#     622       namespace=namespace)
#     623   context = converter.EntityContext(namer, entity_info, program_ctx)
# --> 624   node = node_to_graph(node, context)
#     625
#     626   if isinstance(node, gast.Lambda):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/conversion.py in node_to_graph(node, context)
#     656
#     657   node = converter.standard_analysis(node, context, is_initial=True)
# --> 658   node = converter.apply_(node, context, arg_defaults)
#     659   node = converter.apply_(node, context, directives)
#     660   node = converter.apply_(node, context, break_statements)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/core/converter.py in apply_(node, context, converter_module)
#     377     ast.AST, the result of applying converter to node
#     378   """
# --> 379   node = standard_analysis(node, context)
#     380   node = converter_module.transform(node, context)
#     381   return node
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/core/converter.py in standard_analysis(node, context, is_initial)
#     355   node = activity.resolve(node, context, None)
#     356   node = reaching_definitions.resolve(node, context, graphs, AnnotatedDef)
# --> 357   node = liveness.resolve(node, context, graphs)
#     358   if is_initial:
#     359     anno.dup(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py in resolve(node, source_info, graphs)
#     249   """
#     250   cross_function_analyzer = WholeTreeAnalyzer(source_info, graphs)
# --> 251   node = cross_function_analyzer.visit(node)
#     252   visitor = Annotator(source_info, cross_function_analyzer)
#     253   node = visitor.visit(node)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     478
#     479     if not anno.hasanno(node, anno.Basic.SKIP_PROCESSING):
# --> 480       result = super(Base, self).visit(node)
#     481     self.ctx.current_origin = parent_origin
#     482
#
# ~/anaconda3/lib/python3.6/ast.py in visit(self, node)
#     251         method = 'visit_' + node.__class__.__name__
#     252         visitor = getattr(self, method, self.generic_visit)
# --> 253         return visitor(node)
#     254
#     255     def generic_visit(self, node):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py in visit_FunctionDef(self, node)
#     120     analyzer = Analyzer(subgraph)
#     121     self.current_analyzer = analyzer
# --> 122     node = self.generic_visit(node)
#     123     analyzer.visit_reverse()
#     124
#
# ~/anaconda3/lib/python3.6/ast.py in generic_visit(self, node)
#     306                 for value in old_value:
#     307                     if isinstance(value, AST):
# --> 308                         value = self.visit(value)
#     309                         if value is None:
#     310                             continue
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     478
#     479     if not anno.hasanno(node, anno.Basic.SKIP_PROCESSING):
# --> 480       result = super(Base, self).visit(node)
#     481     self.ctx.current_origin = parent_origin
#     482
#
# ~/anaconda3/lib/python3.6/ast.py in visit(self, node)
#     251         method = 'visit_' + node.__class__.__name__
#     252         visitor = getattr(self, method, self.generic_visit)
# --> 253         return visitor(node)
#     254
#     255     def generic_visit(self, node):
#
# ~/anaconda3/lib/python3.6/ast.py in generic_visit(self, node)
#     306                 for value in old_value:
#     307                     if isinstance(value, AST):
# --> 308                         value = self.visit(value)
#     309                         if value is None:
#     310                             continue
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     478
#     479     if not anno.hasanno(node, anno.Basic.SKIP_PROCESSING):
# --> 480       result = super(Base, self).visit(node)
#     481     self.ctx.current_origin = parent_origin
#     482
#
# ~/anaconda3/lib/python3.6/ast.py in visit(self, node)
#     251         method = 'visit_' + node.__class__.__name__
#     252         visitor = getattr(self, method, self.generic_visit)
# --> 253         return visitor(node)
#     254
#     255     def generic_visit(self, node):
#
# ~/anaconda3/lib/python3.6/ast.py in generic_visit(self, node)
#     306                 for value in old_value:
#     307                     if isinstance(value, AST):
# --> 308                         value = self.visit(value)
#     309                         if value is None:
#     310                             continue
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     477       entry_expr_value = node.value
#     478
# --> 479     if not anno.hasanno(node, anno.Basic.SKIP_PROCESSING):
#     480       result = super(Base, self).visit(node)
#     481     self.ctx.current_origin = parent_origin
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/pyct/anno.py in hasanno(node, key, field_name)
#     111
#     112 def hasanno(node, key, field_name='___pyct_anno'):
# --> 113   return hasattr(node, field_name) and key in getattr(node, field_name)
#     114
#     115
#
# ~/anaconda3/lib/python3.6/enum.py in __hash__(self)
#     579         return cls.__format__(val, format_spec)
#     580
# --> 581     def __hash__(self):
#     582         return hash(self._name_)
#     583
#
# KeyboardInterrupt:

# %%
import gym
import numpy as np

from stable_baselines.sac.policies import MlpPolicy
from stable_baselines import SAC

env = gym.make('CartPole-v1')

model = SAC(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=50000, log_interval=10)
model.save("CartPole-v1")

del model # remove to demonstrate saving and loading

model = SAC.load("CartPole-v1")

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-86fc681fb3fb> in <module>()
#       7 env = gym.make('CartPole-v1')
#       8
# ----> 9 model = SAC(MlpPolicy, env, verbose=1)
#      10 model.learn(total_timesteps=50000, log_interval=10)
#      11 model.save("CartPole-v1")
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/sac.py in __init__(self, policy, env, gamma, learning_rate, buffer_size, learning_starts, train_freq, batch_size, tau, ent_coef, target_update_interval, gradient_steps, target_entropy, action_noise, random_exploration, verbose, tensorboard_log, _init_setup_model, policy_kwargs, full_tensorboard_log, seed, n_cpu_tf_sess)
#     136
#     137         if _init_setup_model:
# --> 138             self.setup_model()
#     139
#     140     def _get_pretrain_placeholders(self):
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/sac.py in setup_model(self)
#     156                     # Create policy and target TF objects
#     157                     self.policy_tf = self.policy(self.sess, self.observation_space, self.action_space,
# --> 158                                                  **self.policy_kwargs)
#     159                     self.target_policy = self.policy(self.sess, self.observation_space, self.action_space,
#     160                                                      **self.policy_kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py in __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse, **_kwargs)
#     342     def __init__(self, sess, ob_space, ac_space, n_env=1, n_steps=1, n_batch=None, reuse=False, **_kwargs):
#     343         super(MlpPolicy, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse,
# --> 344                                         feature_extraction="mlp", **_kwargs)
#     345
#     346
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py in __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse, layers, cnn_extractor, feature_extraction, reg_weight, layer_norm, act_fun, **kwargs)
#     183                  layer_norm=False, act_fun=tf.nn.relu, **kwargs):
#     184         super(FeedForwardPolicy, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch,
# --> 185                                                 reuse=reuse, scale=(feature_extraction == "cnn"))
#     186
#     187         self._kwargs_check(feature_extraction, kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/sac/policies.py in __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse, scale)
#      99     def __init__(self, sess, ob_space, ac_space, n_env=1, n_steps=1, n_batch=None, reuse=False, scale=False):
#     100         super(SACPolicy, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=reuse, scale=scale)
# --> 101         assert isinstance(ac_space, Box), "Error: the action space must be of type gym.spaces.Box"
#     102
#     103         self.qf1 = None
#
# AssertionError: Error: the action space must be of type gym.spaces.Box
