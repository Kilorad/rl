# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# multiprocess environment
env = make_vec_env('CartPole-v1', n_envs=4)

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")

del model # remove to demonstrate saving and loading

model = PPO2.load("ppo2_cartpole")

# Enjoy trained agent
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    #env.render()

# %%
import sys
sys.path.insert(1, './env')
sys.path.insert(1, './agents')
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import aa_gun
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

report = []

done_max = 5
resets_max = 140

for estimation in range(done_max):
    # multiprocess environment
    #env=aa_gun.AA_gun_simple0_env(fast_planes=True,long_projectiles=True,random_speed=True)
    env = make_vec_env('Seaquest-ramNoFrameskip-v0', n_envs=3)
    #env = make_vec_env(env, n_envs=4)

    model = PPO2(MlpPolicy, env, verbose=0)
    model.learn(total_timesteps=12000)
    

    # Enjoy trained agent
    
    obs = env.reset()
    episode=0
    rew_episodes=[]
    reward_list=[]
    print('ESIMATION',estimation)
    while True:
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        reward_list.append(rewards)
        #env.render()
        if np.any(dones):
            rew_episodes.append(np.sum(reward_list))
            print('EPISODE',episode,'rew',np.sum(reward_list),dones)
            obs = env.reset()
            reward_list=[]
            episode+=1
        if episode>resets_max:
            break
    report.append(np.mean(rew_episodes))
    plt.plot(rew_episodes)
    plt.show()
# Out:
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08903334a8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08903334a8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08903334a8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f08903334a8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0890333630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0890333630>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0890333630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0890333630>>: AttributeError: module 'gast' has no attribute 'Num'
# ESIMATION 0
# EPISODE 0 rew 140.0 [False False  True]
# EPISODE 1 rew 180.0 [ True False False]
# EPISODE 2 rew 600.0 [False False  True]
# EPISODE 3 rew 500.0 [False  True False]
# EPISODE 4 rew 680.0 [False False  True]
# EPISODE 5 rew 380.0 [ True False False]
# EPISODE 6 rew 400.0 [False False  True]
# EPISODE 7 rew 220.0 [False  True False]
# EPISODE 8 rew 160.0 [False False  True]
# EPISODE 9 rew 60.0 [False  True False]
# EPISODE 10 rew 200.0 [False  True False]
# EPISODE 11 rew 420.0 [ True False False]
# EPISODE 12 rew 100.0 [ True False False]
# EPISODE 13 rew 240.0 [ True False False]
# EPISODE 14 rew 200.0 [ True False False]
# EPISODE 15 rew 240.0 [False  True False]
# EPISODE 16 rew 180.0 [ True False False]
# EPISODE 17 rew 200.0 [False  True False]
# EPISODE 18 rew 380.0 [False  True False]
# EPISODE 19 rew 240.0 [False False  True]
# EPISODE 20 rew 240.0 [False False  True]
# EPISODE 21 rew 240.0 [ True False False]
# EPISODE 22 rew 320.0 [False False  True]
# EPISODE 23 rew 180.0 [ True False False]
# EPISODE 24 rew 120.0 [False False  True]
# EPISODE 25 rew 420.0 [False False  True]
# EPISODE 26 rew 200.0 [False  True False]
# EPISODE 27 rew 120.0 [ True False False]
# EPISODE 28 rew 620.0 [ True False False]
# EPISODE 29 rew 400.0 [False  True False]
# EPISODE 30 rew 180.0 [False  True False]
# EPISODE 97 rew 300.0 [ True False False]
# EPISODE 98 rew 640.0 [ True False False]
# EPISODE 99 rew 320.0 [False False  True]
# EPISODE 100 rew 440.0 [False False  True]
# EPISODE 101 rew 1160.0 [False  True False]
# EPISODE 102 rew 400.0 [False  True False]
# EPISODE 103 rew 420.0 [False False  True]
# EPISODE 104 rew 760.0 [False  True False]
# EPISODE 105 rew 400.0 [ True False False]
# EPISODE 106 rew 440.0 [ True False False]
# EPISODE 107 rew 340.0 [False False  True]
# EPISODE 108 rew 360.0 [False False  True]
# EPISODE 109 rew 120.0 [False False  True]
# EPISODE 110 rew 240.0 [False False  True]
# EPISODE 111 rew 760.0 [False False  True]
# EPISODE 112 rew 180.0 [ True False False]
# EPISODE 113 rew 480.0 [False  True False]
# EPISODE 114 rew 260.0 [False False  True]
# EPISODE 115 rew 480.0 [ True False False]
# EPISODE 116 rew 260.0 [False False  True]
# EPISODE 117 rew 920.0 [False False  True]
# EPISODE 118 rew 380.0 [False False  True]
# EPISODE 119 rew 380.0 [ True False False]
# EPISODE 120 rew 520.0 [False  True False]
# EPISODE 121 rew 360.0 [ True False False]
# EPISODE 122 rew 380.0 [ True False False]
# EPISODE 123 rew 700.0 [False  True False]
# EPISODE 124 rew 520.0 [False  True False]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ec892737d004> in <module>()
#      36     while True:
#      37         action, _states = model.predict(obs)
# ---> 38         obs, rewards, dones, info = env.step(action)
#      39         reward_list.append(rewards)
#      40         #env.render()
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/common/vec_env/base_vec_env.py in step(self, actions)
#     132         """
#     133         self.step_async(actions)
# --> 134         return self.step_wait()
#     135
#     136     def get_images(self):
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in step_wait(self)
#      39         for env_idx in range(self.num_envs):
#      40             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] =\
# ---> 41                 self.envs[env_idx].step(self.actions[env_idx])
#      42             if self.buf_dones[env_idx]:
#      43                 # save final observation where user can get it, then reset
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/bench/monitor.py in step(self, action)
#      82         if self.needs_reset:
#      83             raise RuntimeError("Tried to step environment that needs reset")
# ---> 84         observation, reward, done, info = self.env.step(action)
#      85         self.rewards.append(reward)
#      86         if done:
#
# ~/anaconda3/lib/python3.6/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/atari/atari_env.py in step(self, a)
#     118             num_steps = self.np_random.randint(self.frameskip[0], self.frameskip[1])
#     119         for _ in range(num_steps):
# --> 120             reward += self.ale.act(action)
#     121         ob = self._get_obs()
#     122
#
# ~/anaconda3/lib/python3.6/site-packages/atari_py/ale_python_interface.py in act(self, action)
#     150
#     151     def act(self, action):
# --> 152         return ale_lib.act(self.obj, int(action))
#     153
#     154     def game_over(self):
#
# KeyboardInterrupt:

# %%
plt.plot(rew_episodes)
