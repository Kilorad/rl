# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# multiprocess environment
env = make_vec_env('CartPole-v1', n_envs=4)

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")

del model # remove to demonstrate saving and loading

model = PPO2.load("ppo2_cartpole")

# Enjoy trained agent
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# --------------------------------------
# | approxkl           | 0.00095481385 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.05         |
# | fps                | 775           |
# | n_updates          | 1             |
# | policy_entropy     | 2.8893015     |
# | policy_loss        | -0.0066262074 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 3.81e-06      |
# | total_timesteps    | 512           |
# | value_loss         | 0.013430671   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004111884  |
# | clipfrac           | 0.0           |
# | explained_variance | -3.37         |
# | fps                | 1615          |
# | n_updates          | 2             |
# | policy_entropy     | 2.8869228     |
# | policy_loss        | -0.0032833717 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.661         |
# | total_timesteps    | 1024          |
# | value_loss         | 0.02671501    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020695628 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0537        |
# | fps                | 1443          |
# | n_updates          | 3             |
# | policy_entropy     | 2.884502      |
# | policy_loss        | -0.0005141848 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.979         |
# | total_timesteps    | 1536          |
# | value_loss         | 6.72654       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011863468 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.494         |
# | fps                | 1508          |
# | n_updates          | 4             |
# | policy_entropy     | 2.8838742     |
# | policy_loss        | -0.001510259  |
# | serial_timesteps   | 512           |
# | time_elapsed       | 1.33          |
# | total_timesteps    | 2048          |
# | value_loss         | 0.016592521   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.6693367e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0516         |
# | fps                | 1531           |
# | n_updates          | 5              |
# | policy_entropy     | 2.8845332      |
# | policy_loss        | -0.00075550727 |
# | serial_timesteps   | 640            |
# | time_elapsed       | 1.68           |
# | total_timesteps    | 2560           |
# | value_loss         | 3.147371       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.6036828e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0273         |
# | fps                | 1555           |
# | n_updates          | 6              |
# | policy_entropy     | 2.8842297      |
# | policy_loss        | -0.00012614363 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 2.01           |
# | total_timesteps    | 3072           |
# | value_loss         | 3.0199172      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00012472646 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0587       |
# | fps                | 1448          |
# | n_updates          | 7             |
# | policy_entropy     | 2.8852372     |
# | policy_loss        | -0.0013629026 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 2.34          |
# | total_timesteps    | 3584          |
# | value_loss         | 3.4457176     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012612829 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00614       |
# | fps                | 1487          |
# | n_updates          | 8             |
# | policy_entropy     | 2.8838923     |
# | policy_loss        | -0.0006549957 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 2.7           |
# | total_timesteps    | 4096          |
# | value_loss         | 6.6844864     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.508554e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00839      |
# | fps                | 1509          |
# | n_updates          | 9             |
# | policy_entropy     | 2.883429      |
# | policy_loss        | -0.0013339104 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 3.04          |
# | total_timesteps    | 4608          |
# | value_loss         | 3.2679968     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000115642986 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0151         |
# | fps                | 1484           |
# | n_updates          | 10             |
# | policy_entropy     | 2.8824852      |
# | policy_loss        | 0.00012935791  |
# | serial_timesteps   | 1280           |
# | time_elapsed       | 3.38           |
# | total_timesteps    | 5120           |
# | value_loss         | 9.124487       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.99273e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0597        |
# | fps                | 1491          |
# | n_updates          | 11            |
# | policy_entropy     | 2.8821604     |
# | policy_loss        | -0.0010530837 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 3.73          |
# | total_timesteps    | 5632          |
# | value_loss         | 3.1139042     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.0651335e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0865        |
# | fps                | 1522          |
# | n_updates          | 12            |
# | policy_entropy     | 2.882177      |
# | policy_loss        | -0.0008548946 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 4.07          |
# | total_timesteps    | 6144          |
# | value_loss         | 5.822055      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021231831 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.321         |
# | fps                | 1634          |
# | n_updates          | 13            |
# | policy_entropy     | 2.8825526     |
# | policy_loss        | -0.0032069536 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 4.41          |
# | total_timesteps    | 6656          |
# | value_loss         | 0.034197558   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019557962 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0715        |
# | fps                | 1543          |
# | n_updates          | 14            |
# | policy_entropy     | 2.8831494     |
# | policy_loss        | -0.0021287794 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 4.73          |
# | total_timesteps    | 7168          |
# | value_loss         | 2.8307624     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014458943 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00202       |
# | fps                | 1621          |
# | n_updates          | 15            |
# | policy_entropy     | 2.8830447     |
# | policy_loss        | -0.0016742931 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 5.06          |
# | total_timesteps    | 7680          |
# | value_loss         | 3.1927888     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018809887 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | -0.0177       |
# | fps                | 1384          |
# | n_updates          | 16            |
# | policy_entropy     | 2.8834672     |
# | policy_loss        | -0.0032932507 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 5.38          |
# | total_timesteps    | 8192          |
# | value_loss         | 2.9250073     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00054246467 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | 0.61          |
# | fps                | 1479          |
# | n_updates          | 17            |
# | policy_entropy     | 2.8844275     |
# | policy_loss        | -0.004648895  |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 5.75          |
# | total_timesteps    | 8704          |
# | value_loss         | 0.017406123   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00020817896  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 1.92e+03       |
# | ep_reward_mean     | 40             |
# | explained_variance | 0.0134         |
# | fps                | 1657           |
# | n_updates          | 18             |
# | policy_entropy     | 2.8839774      |
# | policy_loss        | -0.00045648837 |
# | serial_timesteps   | 2304           |
# | time_elapsed       | 6.1            |
# | total_timesteps    | 9216           |
# | value_loss         | 5.7498937      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00017349067 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | 0.409         |
# | fps                | 1688          |
# | n_updates          | 19            |
# | policy_entropy     | 2.88386       |
# | policy_loss        | -0.0038580294 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 6.41          |
# | total_timesteps    | 9728          |
# | value_loss         | 0.024964483   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017906254 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | 0.0443        |
# | fps                | 1649          |
# | n_updates          | 20            |
# | policy_entropy     | 2.8847182     |
# | policy_loss        | -0.0010970999 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 6.71          |
# | total_timesteps    | 10240         |
# | value_loss         | 6.3880115     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.8081975e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | 0.106         |
# | fps                | 1570          |
# | n_updates          | 21            |
# | policy_entropy     | 2.8836422     |
# | policy_loss        | -0.000912911  |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 7.02          |
# | total_timesteps    | 10752         |
# | value_loss         | 3.1119528     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00028159388 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | 0.132         |
# | fps                | 1619          |
# | n_updates          | 22            |
# | policy_entropy     | 2.8829727     |
# | policy_loss        | -0.0035641377 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 7.35          |
# | total_timesteps    | 11264         |
# | value_loss         | 0.017874131   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026506206 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | 0.0646        |
# | fps                | 1575          |
# | n_updates          | 23            |
# | policy_entropy     | 2.8822916     |
# | policy_loss        | -0.0015499468 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 7.67          |
# | total_timesteps    | 11776         |
# | value_loss         | 2.0537858     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024101275 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 1.92e+03      |
# | ep_reward_mean     | 40            |
# | explained_variance | 0.597         |
# | fps                | 1510          |
# | n_updates          | 24            |
# | policy_entropy     | 2.8813467     |
# | policy_loss        | -0.0033056983 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 8             |
# | total_timesteps    | 12288         |
# | value_loss         | 0.017502971   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00027571162  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 2.56e+03       |
# | ep_reward_mean     | 80             |
# | explained_variance | 0.0267         |
# | fps                | 1486           |
# | n_updates          | 25             |
# | policy_entropy     | 2.8802755      |
# | policy_loss        | -0.00086465303 |
# | serial_timesteps   | 3200           |
# | time_elapsed       | 8.34           |
# | total_timesteps    | 12800          |
# | value_loss         | 12.783969      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.5632565e-05  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 2.56e+03       |
# | ep_reward_mean     | 80             |
# | explained_variance | 0.0372         |
# | fps                | 1559           |
# | n_updates          | 26             |
# | policy_entropy     | 2.8801816      |
# | policy_loss        | -0.00087955873 |
# | serial_timesteps   | 3328           |
# | time_elapsed       | 8.68           |
# | total_timesteps    | 13312          |
# | value_loss         | 5.582836       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00010641866 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 2.56e+03      |
# | ep_reward_mean     | 80            |
# | explained_variance | 0.0538        |
# | fps                | 1608          |
# | n_updates          | 27            |
# | policy_entropy     | 2.8790615     |
# | policy_loss        | -0.0020474105 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 9.01          |
# | total_timesteps    | 13824         |
# | value_loss         | 6.2614403     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021565788 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 2.56e+03      |
# | ep_reward_mean     | 80            |
# | explained_variance | 0.188         |
# | fps                | 1628          |
# | n_updates          | 28            |
# | policy_entropy     | 2.8795469     |
# | policy_loss        | -0.0039429534 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 9.33          |
# | total_timesteps    | 14336         |
# | value_loss         | 0.04110388    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023664458 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 2.56e+03      |
# | ep_reward_mean     | 80            |
# | explained_variance | -0.000902     |
# | fps                | 1440          |
# | n_updates          | 29            |
# | policy_entropy     | 2.8795426     |
# | policy_loss        | -0.0013329783 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 9.65          |
# | total_timesteps    | 14848         |
# | value_loss         | 6.523612      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022254832 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 2.56e+03      |
# | ep_reward_mean     | 80            |
# | explained_variance | 0.717         |
# | fps                | 1482          |
# | n_updates          | 30            |
# | policy_entropy     | 2.8770137     |
# | policy_loss        | -0.0027766386 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 10            |
# | total_timesteps    | 15360         |
# | value_loss         | 0.016431525   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011850402 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 2.56e+03      |
# | ep_reward_mean     | 80            |
# | explained_variance | -0.00841      |
# | fps                | 1524          |
# | n_updates          | 31            |
# | policy_entropy     | 2.8754508     |
# | policy_loss        | -0.0021339864 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 10.4          |
# | total_timesteps    | 15872         |
# | value_loss         | 9.456855      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.0544156e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 2.56e+03      |
# | ep_reward_mean     | 80            |
# | explained_variance | 0.0519        |
# | fps                | 1479          |
# | n_updates          | 32            |
# | policy_entropy     | 2.8755956     |
# | policy_loss        | -0.0009146634 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 10.7          |
# | total_timesteps    | 16384         |
# | value_loss         | 9.373009      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019831311 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 2.56e+03      |
# | ep_reward_mean     | 80            |
# | explained_variance | -0.261        |
# | fps                | 1586          |
# | n_updates          | 33            |
# | policy_entropy     | 2.8775926     |
# | policy_loss        | -0.0031448803 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 11            |
# | total_timesteps    | 16896         |
# | value_loss         | 0.044932418   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00024902768  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 2.56e+03       |
# | ep_reward_mean     | 80             |
# | explained_variance | 0.000196       |
# | fps                | 1476           |
# | n_updates          | 34             |
# | policy_entropy     | 2.8770115      |
# | policy_loss        | -0.00085522316 |
# | serial_timesteps   | 4352           |
# | time_elapsed       | 11.4           |
# | total_timesteps    | 17408          |
# | value_loss         | 8.010448       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.370365e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.17e+03      |
# | ep_reward_mean     | 133           |
# | explained_variance | 0.0779        |
# | fps                | 1656          |
# | n_updates          | 35            |
# | policy_entropy     | 2.87531       |
# | policy_loss        | -0.0011094513 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 11.7          |
# | total_timesteps    | 17920         |
# | value_loss         | 3.1644871     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 7.158327e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 3.51e+03     |
# | ep_reward_mean     | 165          |
# | explained_variance | 0.0481       |
# | fps                | 1460         |
# | n_updates          | 36           |
# | policy_entropy     | 2.8765054    |
# | policy_loss        | 7.386814e-05 |
# | serial_timesteps   | 4608         |
# | time_elapsed       | 12           |
# | total_timesteps    | 18432        |
# | value_loss         | 3.1446688    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.000117345684 |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 3.51e+03       |
# | ep_reward_mean     | 165            |
# | explained_variance | 0.0218         |
# | fps                | 1545           |
# | n_updates          | 37             |
# | policy_entropy     | 2.8749757      |
# | policy_loss        | -0.00082081836 |
# | serial_timesteps   | 4736           |
# | time_elapsed       | 12.4           |
# | total_timesteps    | 18944          |
# | value_loss         | 6.3326793      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023371792 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.455         |
# | fps                | 1663          |
# | n_updates          | 38            |
# | policy_entropy     | 2.876264      |
# | policy_loss        | -0.0035769194 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 19456         |
# | value_loss         | 0.04895944    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000431119   |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.469         |
# | fps                | 1574          |
# | n_updates          | 39            |
# | policy_entropy     | 2.8779585     |
# | policy_loss        | -0.0050929696 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 13            |
# | total_timesteps    | 19968         |
# | value_loss         | 0.030054217   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002988113  |
# | clipfrac           | 0.00048828125 |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.0653        |
# | fps                | 1642          |
# | n_updates          | 40            |
# | policy_entropy     | 2.8773775     |
# | policy_loss        | -0.0016220454 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 13.3          |
# | total_timesteps    | 20480         |
# | value_loss         | 6.433013      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018783545 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | -0.0241       |
# | fps                | 1640          |
# | n_updates          | 41            |
# | policy_entropy     | 2.8749437     |
# | policy_loss        | -0.0026059884 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 13.7          |
# | total_timesteps    | 20992         |
# | value_loss         | 3.3546576     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001564576  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.0794        |
# | fps                | 1579          |
# | n_updates          | 42            |
# | policy_entropy     | 2.872783      |
# | policy_loss        | -0.0018514653 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 14            |
# | total_timesteps    | 21504         |
# | value_loss         | 5.966684      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0002379095 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 3.37e+03     |
# | ep_reward_mean     | 160          |
# | explained_variance | 0.0457       |
# | fps                | 1607         |
# | n_updates          | 43           |
# | policy_entropy     | 2.8709128    |
# | policy_loss        | -0.00249531  |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 14.3         |
# | total_timesteps    | 22016        |
# | value_loss         | 1.0611211    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00029855486 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.108         |
# | fps                | 1681          |
# | n_updates          | 44            |
# | policy_entropy     | 2.86942       |
# | policy_loss        | -0.0019616755 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 14.6          |
# | total_timesteps    | 22528         |
# | value_loss         | 3.089337      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.145723e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.0658        |
# | fps                | 1574          |
# | n_updates          | 45            |
# | policy_entropy     | 2.8657312     |
# | policy_loss        | -0.0015543125 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 14.9          |
# | total_timesteps    | 23040         |
# | value_loss         | 6.057267      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 7.126617e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 3.37e+03     |
# | ep_reward_mean     | 160          |
# | explained_variance | 0.0293       |
# | fps                | 1488         |
# | n_updates          | 46           |
# | policy_entropy     | 2.8587048    |
# | policy_loss        | -0.000490276 |
# | serial_timesteps   | 5888         |
# | time_elapsed       | 15.2         |
# | total_timesteps    | 23552        |
# | value_loss         | 8.144684     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.145806e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.0325        |
# | fps                | 1545          |
# | n_updates          | 47            |
# | policy_entropy     | 2.8593352     |
# | policy_loss        | -0.0012133267 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 15.6          |
# | total_timesteps    | 24064         |
# | value_loss         | 6.126945      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010640182 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 3.37e+03      |
# | ep_reward_mean     | 160           |
# | explained_variance | 0.153         |
# | fps                | 1645          |
# | n_updates          | 48            |
# | policy_entropy     | 2.8603334     |
# | policy_loss        | -0.0029377816 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 15.9          |
# | total_timesteps    | 24576         |
# | value_loss         | 2.9164715     |
# --------------------------------------
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# ...
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# Render not defined for <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f988282ca90>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4cd3ebd6948a> in <module>
#      24     action, _states = model.predict(obs)
#      25     obs, rewards, dones, info = env.step(action)
# ---> 26     env.render()
#
# ~/.local/lib/python3.7/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in render(self, *args, **kwargs)
#      65             return self.envs[0].render(*args, **kwargs)
#      66         else:
# ---> 67             return super().render(*args, **kwargs)
#      68
#      69     def _save_obs(self, env_idx, obs):
#
# ~/.local/lib/python3.7/site-packages/stable_baselines/common/vec_env/base_vec_env.py in render(self, *args, **kwargs)
#     146         :param mode: (str) the rendering type
#     147         """
# --> 148         logger.warn('Render not defined for %s' % self)
#     149
#     150     @property
#
# ~/.local/lib/python3.7/site-packages/stable_baselines/logger.py in warn(*args)
#     367     :param args: (list) log the arguments
#     368     """
# --> 369     log(*args, level=WARN)
#     370
#     371
#
# ~/.local/lib/python3.7/site-packages/stable_baselines/logger.py in log(level, *args)
#     334     :param level: (int) the logging level (can be DEBUG=10, INFO=20, WARN=30, ERROR=40, DISABLED=50)
#     335     """
# --> 336     Logger.CURRENT.log(*args, level=level)
#     337
#     338
#
# ~/.local/lib/python3.7/site-packages/stable_baselines/logger.py in log(self, level, *args)
#     524         """
#     525         if self.level <= level:
# --> 526             self._do_log(args)
#     527
#     528     # Configuration
#
# ~/.local/lib/python3.7/site-packages/stable_baselines/logger.py in _do_log(self, args)
#     562         for fmt in self.output_formats:
#     563             if isinstance(fmt, SeqWriter):
# --> 564                 fmt.writeseq(map(str, args))
#     565
#     566
#
# ~/.local/lib/python3.7/site-packages/stable_baselines/logger.py in writeseq(self, seq)
#     111                 self.file.write(' ')
#     112         self.file.write('\n')
# --> 113         self.file.flush()
#     114
#     115     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in flush(self)
#     347                 self.pub_thread.schedule(evt.set)
#     348                 # and give a timeout to avoid
# --> 349                 if not evt.wait(self.flush_timeout):
#     350                     # write directly to __stderr__ instead of warning because
#     351                     # if this is happening sys.stderr may be the problem.
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
#if (e in range(2,7)) or (e in range(20,25)) or (e in range(100,103)) or (e in range(200,202)) or (e in range(300,306)) or (e in range(400,406)) or (e in range(500,506)) or (e in range(600,604)):
                #    if agent.render:
                #        env.render()

# %%
import sys
sys.path.insert(1, './env')
sys.path.insert(1, './agents')
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import aa_gun

report = []

done_max = 5
resets_max = 140

for estimation in range(done_max):
    # multiprocess environment
    env=aa_gun.AA_gun_simple0_env(fast_planes=True,long_projectiles=True,random_speed=True)
    #env = make_vec_env(env, n_envs=4)

    model = PPO2(MlpPolicy, env, verbose=0)
    model.learn(total_timesteps=12000)
    

    # Enjoy trained agent
    
    obs = env.reset()
    episode=0
    rew_episodes=[]
    reward_list=[]
    print('ESIMATION',estimation)
    while True:
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        reward_list.append(rewards)
        env.render()
        if dones:
            rew_episodes.append(np.sum(reward_list))
            print('EPISODE',episode,'rew',np.sum(reward_list))
            obs = env.reset()
            reward_list=[]
            episode+=1
        if episode>resets_max:
            break
    report.append(np.mean(rew_episodes))
    plt.plot(rew_episodes)
    plt.show()
# Out:
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# ESIMATION 0
# EPISODE 0 rew 0.3125
# hit
# EPISODE 1 rew 1.5
# EPISODE 2 rew 0.625
# EPISODE 3 rew 0.75
# hit
# EPISODE 4 rew 1.5625
# EPISODE 5 rew 1.0625
# EPISODE 6 rew 1.0
# EPISODE 7 rew 0.9375
# hit
# EPISODE 8 rew 2.0
# EPISODE 9 rew 0.5625
# EPISODE 10 rew 0.6875
# EPISODE 11 rew 1.6875
# hit
# hit
# EPISODE 12 rew 2.1875
# EPISODE 13 rew 1.0
# EPISODE 14 rew 0.5
# EPISODE 15 rew 0.9375
# EPISODE 16 rew 1.375
# hit
# EPISODE 17 rew 1.375
# hit
# hit
# EPISODE 18 rew 2.4375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0b4bbf6c2448> in <module>
#      34         obs, rewards, dones, info = env.step(action)
#      35         reward_list.append(rewards)
# ---> 36         env.render()
#      37         if dones:
#      38             rew_episodes.append(np.sum(reward_list))
#
# ~/Python/rl/rl/env/aa_gun.py in render(self, mode)
#     429         if self.state is None: return None
#     430
# --> 431         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     432     def render2(self, mode='human'):
#     433         screen_width = 600
#
# ~/.local/lib/python3.7/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#      95         self.transform.enable()
#      96         for geom in self.geoms:
# ---> 97             geom.render()
#      98         for geom in self.onetime_geoms:
#      99             geom.render()
#
# ~/.local/lib/python3.7/site-packages/gym/envs/classic_control/rendering.py in render(self)
#     165         for attr in reversed(self.attrs):
#     166             attr.enable()
# --> 167         self.render1()
#     168         for attr in self.attrs:
#     169             attr.disable()
#
# ~/.local/lib/python3.7/site-packages/gym/envs/classic_control/rendering.py in render1(self)
#     238         else: glBegin(GL_TRIANGLES)
#     239         for p in self.v:
# --> 240             glVertex3f(p[0], p[1],0)  # draw each vertex
#     241         glEnd()
#     242
#
# ~/.local/lib/python3.7/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      83     pass
#      84
# ---> 85 def errcheck(result, func, arguments):
#      86     if _debug_gl_trace:
#      87         try:
#
# KeyboardInterrupt:

# %%
plt.plot(rew_episodes)

# %%
report
