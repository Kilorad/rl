# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# multiprocess environment
env = make_vec_env('CartPole-v1', n_envs=4)

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")

del model # remove to demonstrate saving and loading

model = PPO2.load("ppo2_cartpole")

# Enjoy trained agent
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    #env.render()
# Out:
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:58: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/policies.py:115: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/common/policies.py:560: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7108738be0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7108738be0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7108738be0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7108738be0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/a2c/utils.py:156: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f71085012e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f71085012e8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f71085012e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f71085012e8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:194: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/s.dovgan/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:210: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/s.dovgan/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:246: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# --------------------------------------
# | approxkl           | 0.00013641306 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 19.3          |
# | ep_reward_mean     | 19.3          |
# | explained_variance | -0.0116       |
# | fps                | 969           |
# | n_updates          | 1             |
# | policy_entropy     | 0.69304115    |
# | policy_loss        | -0.0011294127 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 3.81e-06      |
# | total_timesteps    | 512           |
# | value_loss         | 36.53705      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.97815e-05   |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 20.9          |
# | ep_reward_mean     | 20.9          |
# | explained_variance | 0.00993       |
# | fps                | 4204          |
# | n_updates          | 2             |
# | policy_entropy     | 0.69253373    |
# | policy_loss        | -0.0015596047 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.529         |
# | total_timesteps    | 1024          |
# | value_loss         | 44.06448      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019733106 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 20.8          |
# | ep_reward_mean     | 20.8          |
# | explained_variance | -0.0102       |
# | fps                | 2243          |
# | n_updates          | 3             |
# | policy_entropy     | 0.6906873     |
# | policy_loss        | -0.002816281  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.653         |
# | total_timesteps    | 1536          |
# | value_loss         | 33.89743      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026652514 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 21            |
# | ep_reward_mean     | 21            |
# | explained_variance | 0.0117        |
# | fps                | 3977          |
# | n_updates          | 4             |
# | policy_entropy     | 0.6876846     |
# | policy_loss        | -0.0032675345 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 0.882         |
# | total_timesteps    | 2048          |
# | value_loss         | 41.205177     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027916214 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 22.9          |
# | ep_reward_mean     | 22.9          |
# | explained_variance | 0.00539       |
# | fps                | 4024          |
# | n_updates          | 5             |
# | policy_entropy     | 0.68404335    |
# | policy_loss        | -0.004208754  |
# | serial_timesteps   | 640           |
# | time_elapsed       | 1.01          |
# | total_timesteps    | 2560          |
# | value_loss         | 49.935658     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020541967 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 24.9          |
# | ep_reward_mean     | 24.9          |
# | explained_variance | 0.0184        |
# | fps                | 3776          |
# | n_updates          | 6             |
# | policy_entropy     | 0.6795091     |
# | policy_loss        | -0.0025454774 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 1.14          |
# | total_timesteps    | 3072          |
# | value_loss         | 55.37485      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018590278 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 26.3          |
# | ep_reward_mean     | 26.3          |
# | explained_variance | -0.0115       |
# | fps                | 4057          |
# | n_updates          | 7             |
# | policy_entropy     | 0.6736248     |
# | policy_loss        | -0.0028533041 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 1.28          |
# | total_timesteps    | 3584          |
# | value_loss         | 56.789192     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.735388e-05   |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 28.4           |
# | ep_reward_mean     | 28.4           |
# | explained_variance | -0.00336       |
# | fps                | 4265           |
# | n_updates          | 8              |
# | policy_entropy     | 0.66788584     |
# | policy_loss        | -0.00045138167 |
# | serial_timesteps   | 1024           |
# | time_elapsed       | 1.4            |
# | total_timesteps    | 4096           |
# | value_loss         | 50.455757      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.766245e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 29.5          |
# | ep_reward_mean     | 29.5          |
# | explained_variance | 0.00049       |
# | fps                | 4483          |
# | n_updates          | 9             |
# | policy_entropy     | 0.6618417     |
# | policy_loss        | -0.0011634144 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 1.53          |
# | total_timesteps    | 4608          |
# | value_loss         | 46.24002      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040807313 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 31.7          |
# | ep_reward_mean     | 31.7          |
# | explained_variance | 0.0166        |
# | fps                | 3442          |
# | n_updates          | 10            |
# | policy_entropy     | 0.65957797    |
# | policy_loss        | -0.005331848  |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 1.64          |
# | total_timesteps    | 5120          |
# | value_loss         | 64.75376      |
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-9c4877a14ac7> in <module>()
#      12
#      13 model = PPO2(MlpPolicy, env, verbose=1)
# ---> 14 model.learn(total_timesteps=25000)
#      15 model.save("ppo2_cartpole")
#      16
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     337                 cliprange_vf_now = cliprange_vf(frac)
#     338                 # true_reward is the reward without discount
# --> 339                 obs, returns, masks, actions, values, neglogpacs, states, ep_infos, true_reward = runner.run()
#     340                 self.num_timesteps += self.n_batch
#     341                 ep_info_buf.extend(ep_infos)
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py in run(self)
#     480             if isinstance(self.env.action_space, gym.spaces.Box):
#     481                 clipped_actions = np.clip(actions, self.env.action_space.low, self.env.action_space.high)
# --> 482             self.obs[:], rewards, self.dones, infos = self.env.step(clipped_actions)
#     483             for info in infos:
#     484                 maybe_ep_info = info.get('episode')
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/common/vec_env/base_vec_env.py in step(self, actions)
#     132         """
#     133         self.step_async(actions)
# --> 134         return self.step_wait()
#     135
#     136     def get_images(self):
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in step_wait(self)
#      39         for env_idx in range(self.num_envs):
#      40             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] =\
# ---> 41                 self.envs[env_idx].step(self.actions[env_idx])
#      42             if self.buf_dones[env_idx]:
#      43                 # save final observation where user can get it, then reset
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/bench/monitor.py in step(self, action)
#      82         if self.needs_reset:
#      83             raise RuntimeError("Tried to step environment that needs reset")
# ---> 84         observation, reward, done, info = self.env.step(action)
#      85         self.rewards.append(reward)
#      86         if done:
#
# ~/anaconda3/lib/python3.6/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/classic_control/cartpole.py in step(self, action)
#      97         sintheta = math.sin(theta)
#      98         temp = (force + self.polemass_length * theta_dot * theta_dot * sintheta) / self.total_mass
# ---> 99         thetaacc = (self.gravity * sintheta - costheta* temp) / (self.length * (4.0/3.0 - self.masspole * costheta * costheta / self.total_mass))
#     100         xacc  = temp - self.polemass_length * thetaacc * costheta / self.total_mass
#     101         if self.kinematics_integrator == 'euler':
#
# KeyboardInterrupt:

# %%
import sys
sys.path.insert(1, './env')
sys.path.insert(1, './agents')
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
import aa_gun
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

report = []

done_max = 5
resets_max = 140

for estimation in range(done_max):
    # multiprocess environment
    env=aa_gun.AA_gun_simple0_env(fast_planes=True,long_projectiles=True,random_speed=True)
    #env = make_vec_env('Seaquest-ramNoFrameskip-v0', n_envs=3)
    #env = make_vec_env(env, n_envs=4)

    model = PPO2(MlpPolicy, env, verbose=0)
    model.learn(total_timesteps=100000)
    

    # Enjoy trained agent
    
    obs = env.reset()
    episode=0
    rew_episodes=[]
    reward_list=[]
    print('ESIMATION',estimation)
    while True:
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        reward_list.append(rewards)
        #env.render()
        if np.any(dones):
            rew_episodes.append(np.sum(reward_list))
            print('EPISODE',episode,'rew',np.sum(reward_list),dones)
            obs = env.reset()
            reward_list=[]
            episode+=1
        if episode>resets_max:
            break
    report.append(np.mean(rew_episodes))
    plt.plot(rew_episodes)
    plt.show()
    print('report',np.mean(rew_episodes))
# Out:
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034523630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034523630>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034523630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034523630>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70801445c0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70801445c0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70801445c0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70801445c0>>: AttributeError: module 'gast' has no attribute 'Num'
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# ESIMATION 0
# hit
# EPISODE 0 rew 3.0 True
# EPISODE 1 rew 1.4375 True
# hit
# EPISODE 2 rew 1.8125 True
# hit
# hit
# EPISODE 3 rew 3.375 True
# hit
# EPISODE 4 rew 2.4375 True
# hit
# EPISODE 5 rew 2.3125 True
# hit
# EPISODE 6 rew 2.75 True
# hit
# hit
# hit
# EPISODE 7 rew 3.875 True
# hit
# EPISODE 8 rew 2.375 True
# EPISODE 9 rew 1.25 True
# EPISODE 10 rew 1.375 True
# hit
# EPISODE 11 rew 3.0 True
# EPISODE 12 rew 1.375 True
# hit
# EPISODE 13 rew 1.5625 True
# EPISODE 14 rew 2.375 True
# hit
# hit
# EPISODE 15 rew 4.4375 True
# hit
# EPISODE 16 rew 3.375 True
# hit
# EPISODE 17 rew 2.25 True
# hit
# hit
# EPISODE 18 rew 3.5625 True
# EPISODE 19 rew 1.1875 True
# EPISODE 20 rew 1.625 True
# hit
# EPISODE 21 rew 1.625 True
# hit
# EPISODE 22 rew 1.9375 True
# hit
# EPISODE 23 rew 1.6875 True
# hit
# EPISODE 24 rew 2.375 True
# hit
# EPISODE 25 rew 1.9375 True
# hit
# EPISODE 26 rew 2.0625 True
# hit
# hit
# hit
# EPISODE 27 rew 3.5625 True
# hit
# EPISODE 28 rew 2.125 True
# hit
# EPISODE 29 rew 2.75 True
# hit
# EPISODE 30 rew 1.25 True
# EPISODE 31 rew 1.25 True
# EPISODE 32 rew 0.75 True
# hit
# hit
# EPISODE 33 rew 3.9375 True
# EPISODE 34 rew 0.375 True
# hit
# EPISODE 35 rew 2.3125 True
# EPISODE 36 rew 0.625 True
# EPISODE 37 rew 1.5625 True
# hit
# EPISODE 38 rew 1.8125 True
# hit
# hit
# EPISODE 39 rew 2.875 True
# hit
# EPISODE 40 rew 2.125 True
# EPISODE 41 rew 0.75 True
# EPISODE 42 rew 1.125 True
# hit
# hit
# EPISODE 43 rew 2.8125 True
# hit
# EPISODE 44 rew 2.25 True
# hit
# hit
# EPISODE 45 rew 2.5625 True
# hit
# EPISODE 46 rew 1.875 True
# EPISODE 47 rew 0.5 True
# hit
# hit
# hit
# EPISODE 48 rew 4.5625 True
# EPISODE 49 rew 1.625 True
# hit
# EPISODE 50 rew 2.6875 True
# hit
# hit
# EPISODE 51 rew 4.1875 True
# hit
# EPISODE 52 rew 1.75 True
# hit
# hit
# hit
# EPISODE 53 rew 5.1875 True
# EPISODE 54 rew 0.1875 True
# hit
# hit
# EPISODE 55 rew 2.8125 True
# hit
# hit
# EPISODE 56 rew 2.75 True
# EPISODE 57 rew 1.625 True
# hit
# hit
# hit
# EPISODE 58 rew 3.375 True
# hit
# EPISODE 59 rew 2.625 True
# hit
# EPISODE 60 rew 1.1875 True
# hit
# EPISODE 61 rew 1.5625 True
# EPISODE 62 rew 1.5625 True
# hit
# EPISODE 63 rew 2.5625 True
# hit
# EPISODE 64 rew 1.75 True
# hit
# EPISODE 65 rew 1.9375 True
# EPISODE 66 rew 0.375 True
# EPISODE 67 rew 0.875 True
# hit
# hit
# EPISODE 68 rew 3.4375 True
# EPISODE 69 rew 2.0 True
# EPISODE 70 rew 1.5 True
# hit
# EPISODE 71 rew 2.5625 True
# hit
# EPISODE 72 rew 1.8125 True
# EPISODE 73 rew 1.25 True
# EPISODE 74 rew 0.5625 True
# hit
# hit
# hit
# EPISODE 75 rew 4.125 True
# hit
# hit
# EPISODE 76 rew 2.25 True
# hit
# EPISODE 77 rew 1.3125 True
# hit
# EPISODE 78 rew 1.9375 True
# hit
# hit
# EPISODE 79 rew 3.5 True
# hit
# EPISODE 80 rew 2.5 True
# hit
# hit
# hit
# EPISODE 81 rew 5.1875 True
# EPISODE 82 rew 1.9375 True
# hit
# EPISODE 83 rew 1.75 True
# hit
# hit
# hit
# EPISODE 84 rew 4.5625 True
# hit
# EPISODE 85 rew 1.875 True
# hit
# hit
# EPISODE 86 rew 3.6875 True
# hit
# hit
# hit
# EPISODE 87 rew 3.25 True
# hit
# EPISODE 88 rew 1.75 True
# hit
# hit
# hit
# EPISODE 89 rew 4.125 True
# hit
# EPISODE 90 rew 1.875 True
# EPISODE 91 rew 1.375 True
# hit
# hit
# EPISODE 92 rew 2.6875 True
# hit
# EPISODE 93 rew 1.8125 True
# hit
# hit
# hit
# EPISODE 94 rew 4.6875 True
# EPISODE 95 rew 0.75 True
# EPISODE 96 rew 2.3125 True
# hit
# hit
# hit
# hit
# EPISODE 97 rew 5.6875 True
# hit
# hit
# EPISODE 98 rew 4.0 True
# hit
# EPISODE 99 rew 2.6875 True
# hit
# hit
# EPISODE 100 rew 2.5625 True
# EPISODE 101 rew 1.4375 True
# EPISODE 102 rew 0.5625 True
# EPISODE 103 rew 1.3125 True
# hit
# hit
# EPISODE 104 rew 3.375 True
# EPISODE 105 rew 1.0 True
# hit
# hit
# EPISODE 106 rew 3.375 True
# hit
# hit
# EPISODE 107 rew 3.0 True
# hit
# EPISODE 108 rew 1.875 True
# hit
# EPISODE 109 rew 2.3125 True
# EPISODE 110 rew 1.3125 True
# hit
# hit
# EPISODE 111 rew 3.4375 True
# hit
# hit
# EPISODE 112 rew 3.0 True
# hit
# hit
# EPISODE 113 rew 2.6875 True
# hit
# hit
# EPISODE 114 rew 4.5625 True
# hit
# EPISODE 115 rew 1.75 True
# hit
# EPISODE 116 rew 2.75 True
# hit
# EPISODE 117 rew 1.9375 True
# EPISODE 118 rew 0.75 True
# hit
# EPISODE 119 rew 2.0625 True
# EPISODE 120 rew 1.1875 True
# hit
# EPISODE 121 rew 2.25 True
# EPISODE 122 rew 1.125 True
# EPISODE 123 rew 0.9375 True
# hit
# EPISODE 124 rew 1.4375 True
# hit
# hit
# hit
# hit
# hit
# EPISODE 125 rew 6.1875 True
# hit
# EPISODE 126 rew 2.875 True
# EPISODE 127 rew 1.125 True
# EPISODE 128 rew 1.3125 True
# hit
# hit
# EPISODE 129 rew 3.0625 True
# hit
# EPISODE 130 rew 1.9375 True
# hit
# EPISODE 131 rew 2.8125 True
# hit
# EPISODE 132 rew 1.625 True
# hit
# EPISODE 133 rew 2.1875 True
# EPISODE 134 rew 1.5 True
# hit
# EPISODE 135 rew 1.8125 True
# hit
# EPISODE 136 rew 2.4375 True
# EPISODE 137 rew 0.875 True
# EPISODE 138 rew 1.3125 True
# hit
# EPISODE 139 rew 1.875 True
# hit
# EPISODE 140 rew 2.1875 True
# report 2.2597517730496453
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70ac08ab38>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70ac08ab38>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70ac08ab38>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70ac08ab38>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034662940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034662940>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034662940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034662940>>: AttributeError: module 'gast' has no attribute 'Num'
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# ESIMATION 1
# EPISODE 0 rew 0.9375 True
# EPISODE 1 rew 0.25 True
# EPISODE 2 rew 0.5625 True
# hit
# hit
# EPISODE 3 rew 2.6875 True
# hit
# EPISODE 4 rew 1.5 True
# EPISODE 5 rew 2.125 True
# EPISODE 6 rew 0.8125 True
# hit
# EPISODE 7 rew 2.3125 True
# EPISODE 8 rew 2.1875 True
# EPISODE 9 rew 1.875 True
# hit
# EPISODE 10 rew 2.3125 True
# hit
# hit
# hit
# EPISODE 11 rew 4.625 True
# EPISODE 12 rew 0.875 True
# hit
# EPISODE 13 rew 2.375 True
# hit
# EPISODE 14 rew 1.75 True
# hit
# hit
# hit
# EPISODE 15 rew 3.8125 True
# EPISODE 16 rew 0.6875 True
# hit
# hit
# EPISODE 17 rew 3.625 True
# EPISODE 18 rew 1.9375 True
# hit
# hit
# EPISODE 19 rew 3.5 True
# hit
# hit
# EPISODE 20 rew 2.4375 True
# EPISODE 21 rew 1.3125 True
# hit
# hit
# EPISODE 22 rew 2.1875 True
# EPISODE 23 rew 0.8125 True
# hit
# EPISODE 24 rew 2.1875 True
# hit
# EPISODE 25 rew 2.0 True
# hit
# hit
# EPISODE 26 rew 3.0 True
# hit
# EPISODE 27 rew 2.1875 True
# EPISODE 28 rew 0.6875 True
# EPISODE 29 rew 0.75 True
# hit
# hit
# EPISODE 30 rew 3.25 True
# hit
# EPISODE 31 rew 2.375 True
# hit
# hit
# EPISODE 32 rew 2.875 True
# EPISODE 33 rew 1.3125 True
# hit
# hit
# hit
# hit
# EPISODE 34 rew 4.9375 True
# hit
# EPISODE 35 rew 2.375 True
# EPISODE 36 rew 1.0 True
# hit
# EPISODE 37 rew 1.5625 True
# hit
# hit
# hit
# EPISODE 38 rew 4.0 True
# hit
# EPISODE 39 rew 2.125 True
# hit
# EPISODE 40 rew 2.1875 True
# EPISODE 41 rew 2.5 True
# hit
# EPISODE 42 rew 1.875 True
# hit
# EPISODE 43 rew 1.5 True
# EPISODE 44 rew 1.9375 True
# EPISODE 45 rew 1.75 True
# hit
# EPISODE 46 rew 3.0 True
# EPISODE 47 rew 0.8125 True
# EPISODE 48 rew 0.6875 True
# EPISODE 49 rew 1.1875 True
# hit
# EPISODE 50 rew 2.8125 True
# EPISODE 51 rew 1.5625 True
# hit
# EPISODE 52 rew 2.8125 True
# hit
# hit
# EPISODE 53 rew 3.5 True
# EPISODE 54 rew 1.125 True
# hit
# EPISODE 55 rew 1.3125 True
# hit
# EPISODE 56 rew 1.9375 True
# EPISODE 57 rew 1.6875 True
# hit
# hit
# hit
# EPISODE 58 rew 4.125 True
# EPISODE 59 rew 1.3125 True
# hit
# EPISODE 60 rew 1.3125 True
# EPISODE 61 rew 0.3125 True
# EPISODE 62 rew 2.25 True
# EPISODE 63 rew 0.4375 True
# hit
# EPISODE 64 rew 1.1875 True
# hit
# EPISODE 65 rew 2.0625 True
# EPISODE 66 rew 0.75 True
# hit
# hit
# EPISODE 67 rew 3.0625 True
# hit
# EPISODE 68 rew 1.5 True
# hit
# EPISODE 69 rew 2.125 True
# EPISODE 70 rew 1.5 True
# hit
# EPISODE 71 rew 1.875 True
# hit
# EPISODE 72 rew 2.1875 True
# hit
# EPISODE 73 rew 2.4375 True
# hit
# EPISODE 74 rew 2.8125 True
# hit
# EPISODE 75 rew 1.4375 True
# hit
# EPISODE 76 rew 2.0625 True
# hit
# EPISODE 77 rew 2.3125 True
# hit
# hit
# hit
# EPISODE 78 rew 4.0 True
# EPISODE 79 rew 1.125 True
# hit
# hit
# EPISODE 80 rew 3.1875 True
# EPISODE 81 rew 1.875 True
# hit
# EPISODE 82 rew 2.25 True
# hit
# EPISODE 83 rew 2.5 True
# EPISODE 84 rew 1.3125 True
# hit
# EPISODE 85 rew 3.0 True
# EPISODE 86 rew 2.0 True
# hit
# EPISODE 87 rew 1.625 True
# hit
# hit
# EPISODE 88 rew 2.6875 True
# hit
# hit
# hit
# EPISODE 89 rew 4.1875 True
# hit
# EPISODE 90 rew 1.75 True
# EPISODE 91 rew 1.8125 True
# hit
# EPISODE 92 rew 2.125 True
# hit
# EPISODE 93 rew 2.25 True
# EPISODE 94 rew 1.25 True
# hit
# EPISODE 95 rew 1.875 True
# EPISODE 96 rew 0.4375 True
# EPISODE 97 rew 1.6875 True
# hit
# EPISODE 98 rew 3.375 True
# hit
# EPISODE 99 rew 2.5 True
# hit
# EPISODE 100 rew 2.0625 True
# EPISODE 101 rew 1.1875 True
# hit
# EPISODE 102 rew 2.8125 True
# hit
# hit
# hit
# EPISODE 103 rew 3.6875 True
# EPISODE 104 rew 0.3125 True
# EPISODE 105 rew 1.1875 True
# hit
# hit
# EPISODE 106 rew 4.0 True
# EPISODE 107 rew 0.875 True
# hit
# EPISODE 108 rew 2.25 True
# EPISODE 109 rew 1.375 True
# hit
# EPISODE 110 rew 1.9375 True
# hit
# EPISODE 111 rew 1.8125 True
# hit
# EPISODE 112 rew 3.125 True
# hit
# EPISODE 113 rew 2.5 True
# hit
# hit
# EPISODE 114 rew 3.25 True
# hit
# hit
# EPISODE 115 rew 3.625 True
# EPISODE 116 rew 0.9375 True
# hit
# EPISODE 117 rew 1.6875 True
# hit
# EPISODE 118 rew 1.625 True
# EPISODE 119 rew 0.875 True
# EPISODE 120 rew 1.3125 True
# hit
# hit
# EPISODE 121 rew 3.5625 True
# hit
# EPISODE 122 rew 2.3125 True
# EPISODE 123 rew 1.125 True
# EPISODE 124 rew 1.0625 True
# EPISODE 125 rew 1.1875 True
# EPISODE 126 rew 0.375 True
# EPISODE 127 rew 1.375 True
# EPISODE 128 rew 1.25 True
# hit
# EPISODE 129 rew 2.375 True
# EPISODE 130 rew 1.125 True
# hit
# EPISODE 131 rew 1.9375 True
# hit
# hit
# EPISODE 132 rew 3.625 True
# hit
# hit
# EPISODE 133 rew 4.0 True
# hit
# hit
# hit
# EPISODE 134 rew 3.75 True
# hit
# hit
# EPISODE 135 rew 3.1875 True
# EPISODE 136 rew 1.25 True
# EPISODE 137 rew 1.5625 True
# EPISODE 138 rew 1.75 True
# hit
# hit
# hit
# EPISODE 139 rew 4.0 True
# EPISODE 140 rew 0.9375 True
# report 2.0452127659574466
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f438>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f438>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f438>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f438>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f208>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f705426f208>>: AttributeError: module 'gast' has no attribute 'Num'
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# ESIMATION 2
# EPISODE 0 rew 0.4375 True
# EPISODE 1 rew 1.875 True
# EPISODE 2 rew 0.75 True
# hit
# hit
# hit
# EPISODE 3 rew 4.875 True
# EPISODE 4 rew 1.125 True
# EPISODE 5 rew 0.875 True
# hit
# EPISODE 6 rew 1.875 True
# hit
# hit
# EPISODE 7 rew 2.6875 True
# EPISODE 8 rew 1.5 True
# hit
# EPISODE 9 rew 1.75 True
# hit
# EPISODE 10 rew 1.625 True
# hit
# hit
# hit
# hit
# EPISODE 11 rew 5.125 True
# hit
# hit
# EPISODE 12 rew 2.6875 True
# hit
# EPISODE 13 rew 3.0 True
# EPISODE 14 rew 1.375 True
# hit
# EPISODE 15 rew 1.375 True
# EPISODE 16 rew 1.125 True
# hit
# EPISODE 17 rew 1.9375 True
# hit
# EPISODE 18 rew 1.4375 True
# EPISODE 19 rew 0.6875 True
# hit
# hit
# EPISODE 20 rew 2.875 True
# hit
# EPISODE 21 rew 1.5625 True
# hit
# EPISODE 22 rew 1.875 True
# hit
# EPISODE 23 rew 1.625 True
# hit
# hit
# hit
# EPISODE 24 rew 3.625 True
# hit
# EPISODE 25 rew 1.3125 True
# EPISODE 26 rew 1.625 True
# hit
# EPISODE 27 rew 1.5625 True
# hit
# hit
# hit
# EPISODE 28 rew 3.625 True
# EPISODE 29 rew 1.5625 True
# hit
# EPISODE 30 rew 2.9375 True
# EPISODE 31 rew 1.625 True
# hit
# EPISODE 32 rew 3.0625 True
# hit
# EPISODE 33 rew 2.5625 True
# hit
# EPISODE 34 rew 1.3125 True
# hit
# EPISODE 35 rew 2.0625 True
# EPISODE 36 rew 1.625 True
# EPISODE 37 rew 0.8125 True
# hit
# hit
# EPISODE 38 rew 2.5625 True
# hit
# hit
# EPISODE 39 rew 2.9375 True
# hit
# hit
# EPISODE 40 rew 3.25 True
# hit
# hit
# EPISODE 41 rew 2.6875 True
# EPISODE 42 rew 1.125 True
# hit
# EPISODE 43 rew 2.9375 True
# hit
# EPISODE 44 rew 3.625 True
# hit
# EPISODE 45 rew 1.8125 True
# hit
# EPISODE 46 rew 1.9375 True
# hit
# hit
# EPISODE 47 rew 2.5 True
# hit
# EPISODE 48 rew 2.375 True
# hit
# hit
# hit
# EPISODE 49 rew 3.5 True
# hit
# EPISODE 50 rew 2.625 True
# hit
# EPISODE 51 rew 1.9375 True
# hit
# hit
# hit
# EPISODE 52 rew 4.1875 True
# EPISODE 53 rew 0.75 True
# hit
# EPISODE 54 rew 2.0 True
# EPISODE 55 rew 2.0 True
# hit
# EPISODE 56 rew 2.4375 True
# hit
# EPISODE 57 rew 1.4375 True
# hit
# hit
# EPISODE 58 rew 3.125 True
# hit
# EPISODE 59 rew 2.1875 True
# EPISODE 60 rew 1.25 True
# EPISODE 61 rew 0.625 True
# EPISODE 62 rew 1.625 True
# hit
# hit
# EPISODE 63 rew 2.6875 True
# hit
# EPISODE 64 rew 2.1875 True
# EPISODE 65 rew 1.25 True
# hit
# hit
# EPISODE 66 rew 3.5 True
# hit
# EPISODE 67 rew 3.375 True
# hit
# hit
# hit
# EPISODE 68 rew 3.25 True
# hit
# EPISODE 69 rew 1.5 True
# hit
# EPISODE 70 rew 1.75 True
# hit
# hit
# EPISODE 71 rew 3.25 True
# EPISODE 72 rew 1.0625 True
# hit
# EPISODE 73 rew 3.125 True
# EPISODE 74 rew 2.4375 True
# EPISODE 75 rew 1.625 True
# EPISODE 76 rew 0.875 True
# EPISODE 77 rew 1.0 True
# EPISODE 78 rew 1.125 True
# hit
# EPISODE 79 rew 2.625 True
# hit
# EPISODE 80 rew 3.25 True
# hit
# hit
# EPISODE 81 rew 2.8125 True
# EPISODE 82 rew 1.625 True
# EPISODE 83 rew 1.125 True
# hit
# hit
# EPISODE 84 rew 2.4375 True
# EPISODE 85 rew 0.75 True
# EPISODE 86 rew 0.75 True
# hit
# hit
# EPISODE 87 rew 3.75 True
# EPISODE 88 rew 0.625 True
# hit
# EPISODE 89 rew 2.625 True
# hit
# EPISODE 90 rew 2.875 True
# EPISODE 91 rew 1.25 True
# hit
# EPISODE 92 rew 2.0625 True
# EPISODE 93 rew 1.6875 True
# hit
# hit
# EPISODE 94 rew 2.9375 True
# hit
# EPISODE 95 rew 2.0 True
# EPISODE 96 rew 1.0 True
# EPISODE 97 rew 0.9375 True
# EPISODE 98 rew 0.375 True
# hit
# hit
# hit
# EPISODE 99 rew 3.25 True
# hit
# EPISODE 100 rew 2.3125 True
# hit
# hit
# hit
# EPISODE 101 rew 3.75 True
# EPISODE 102 rew 0.3125 True
# hit
# EPISODE 103 rew 1.25 True
# EPISODE 104 rew 1.0 True
# EPISODE 105 rew 1.0 True
# EPISODE 106 rew 1.625 True
# EPISODE 107 rew 0.5 True
# hit
# EPISODE 108 rew 3.125 True
# EPISODE 109 rew 0.8125 True
# EPISODE 110 rew 0.625 True
# EPISODE 111 rew 0.3125 True
# hit
# EPISODE 112 rew 2.0 True
# EPISODE 113 rew 1.125 True
# EPISODE 114 rew 1.1875 True
# EPISODE 115 rew 1.3125 True
# hit
# EPISODE 116 rew 1.5 True
# hit
# EPISODE 117 rew 2.0625 True
# EPISODE 118 rew 1.125 True
# EPISODE 119 rew 1.375 True
# hit
# hit
# EPISODE 120 rew 4.6875 True
# EPISODE 121 rew 0.6875 True
# hit
# EPISODE 122 rew 2.0625 True
# hit
# EPISODE 123 rew 2.25 True
# EPISODE 124 rew 0.6875 True
# hit
# hit
# hit
# EPISODE 125 rew 3.375 True
# EPISODE 126 rew 1.9375 True
# EPISODE 127 rew 1.1875 True
# EPISODE 128 rew 0.75 True
# hit
# EPISODE 129 rew 1.375 True
# hit
# hit
# EPISODE 130 rew 2.5625 True
# hit
# EPISODE 131 rew 2.375 True
# EPISODE 132 rew 0.6875 True
# EPISODE 133 rew 0.4375 True
# hit
# EPISODE 134 rew 1.8125 True
# EPISODE 135 rew 1.75 True
# hit
# EPISODE 136 rew 2.25 True
# EPISODE 137 rew 1.875 True
# hit
# hit
# EPISODE 138 rew 2.6875 True
# EPISODE 139 rew 0.9375 True
# hit
# EPISODE 140 rew 1.625 True
# report 1.9423758865248226
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f703441f390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f703441f390>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f703441f390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f703441f390>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034418be0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034418be0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034418be0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f7034418be0>>: AttributeError: module 'gast' has no attribute 'Num'
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# ESIMATION 3
# hit
# hit
# EPISODE 0 rew 3.375 True
# EPISODE 1 rew 1.0 True
# hit
# EPISODE 2 rew 1.375 True
# hit
# EPISODE 3 rew 2.4375 True
# hit
# EPISODE 4 rew 2.5 True
# hit
# EPISODE 5 rew 1.3125 True
# EPISODE 6 rew 1.8125 True
# hit
# EPISODE 7 rew 2.375 True
# hit
# EPISODE 8 rew 2.0 True
# hit
# EPISODE 9 rew 2.875 True
# hit
# hit
# EPISODE 10 rew 2.6875 True
# EPISODE 11 rew 1.3125 True
# EPISODE 12 rew 1.5625 True
# EPISODE 13 rew 0.75 True
# EPISODE 14 rew 0.875 True
# hit
# hit
# hit
# hit
# EPISODE 15 rew 5.0 True
# hit
# hit
# EPISODE 16 rew 2.6875 True
# hit
# hit
# EPISODE 17 rew 3.0625 True
# hit
# hit
# EPISODE 18 rew 3.125 True
# hit
# EPISODE 19 rew 2.875 True
# EPISODE 20 rew 1.375 True
# hit
# EPISODE 21 rew 2.875 True
# hit
# hit
# hit
# EPISODE 22 rew 3.5 True
# hit
# EPISODE 23 rew 2.375 True
# hit
# hit
# EPISODE 24 rew 3.5625 True
# hit
# hit
# EPISODE 25 rew 3.0 True
# hit
# EPISODE 26 rew 2.0625 True
# hit
# EPISODE 27 rew 2.0625 True
# EPISODE 28 rew 1.0 True
# hit
# hit
# hit
# EPISODE 29 rew 4.1875 True
# hit
# EPISODE 30 rew 2.4375 True
# EPISODE 31 rew 1.625 True
# hit
# EPISODE 32 rew 2.1875 True
# hit
# EPISODE 33 rew 2.3125 True
# EPISODE 34 rew 1.6875 True
# hit
# EPISODE 35 rew 1.8125 True
# hit
# EPISODE 36 rew 1.5 True
# hit
# EPISODE 37 rew 2.1875 True
# EPISODE 38 rew 0.6875 True
# hit
# EPISODE 39 rew 2.625 True
# hit
# EPISODE 40 rew 2.25 True
# hit
# hit
# EPISODE 41 rew 3.6875 True
# hit
# hit
# EPISODE 42 rew 4.1875 True
# hit
# hit
# EPISODE 43 rew 2.6875 True
# EPISODE 44 rew 1.5 True
# EPISODE 45 rew 0.9375 True
# hit
# hit
# EPISODE 46 rew 3.25 True
# hit
# EPISODE 47 rew 1.875 True
# hit
# hit
# hit
# EPISODE 48 rew 3.625 True
# hit
# hit
# hit
# hit
# EPISODE 49 rew 5.375 True
# EPISODE 50 rew 0.6875 True
# hit
# EPISODE 51 rew 1.75 True
# hit
# EPISODE 52 rew 1.5 True
# hit
# EPISODE 53 rew 2.0625 True
# EPISODE 54 rew 1.375 True
# hit
# EPISODE 55 rew 1.6875 True
# hit
# EPISODE 56 rew 1.75 True
# hit
# EPISODE 57 rew 2.9375 True
# hit
# EPISODE 58 rew 1.5 True
# hit
# EPISODE 59 rew 1.8125 True
# hit
# hit
# hit
# EPISODE 60 rew 3.0625 True
# hit
# EPISODE 61 rew 3.25 True
# hit
# EPISODE 62 rew 1.6875 True
# hit
# EPISODE 63 rew 2.75 True
# hit
# hit
# EPISODE 64 rew 3.375 True
# EPISODE 65 rew 1.0625 True
# hit
# hit
# EPISODE 66 rew 3.0 True
# hit
# EPISODE 67 rew 2.0625 True
# hit
# EPISODE 68 rew 1.4375 True
# EPISODE 69 rew 1.5625 True
# hit
# EPISODE 70 rew 2.625 True
# hit
# hit
# EPISODE 71 rew 4.125 True
# EPISODE 72 rew 0.625 True
# EPISODE 73 rew 1.375 True
# hit
# EPISODE 74 rew 2.5 True
# EPISODE 75 rew 0.9375 True
# hit
# EPISODE 76 rew 2.25 True
# EPISODE 77 rew 1.1875 True
# hit
# hit
# EPISODE 78 rew 4.1875 True
# hit
# EPISODE 79 rew 2.3125 True
# EPISODE 80 rew 0.875 True
# hit
# hit
# EPISODE 81 rew 2.875 True
# hit
# EPISODE 82 rew 3.125 True
# EPISODE 83 rew 1.0 True
# EPISODE 84 rew 1.0625 True
# hit
# hit
# hit
# EPISODE 85 rew 3.25 True
# hit
# EPISODE 86 rew 1.4375 True
# hit
# EPISODE 87 rew 2.375 True
# EPISODE 88 rew 1.5 True
# EPISODE 89 rew 0.875 True
# hit
# EPISODE 90 rew 2.0625 True
# EPISODE 91 rew 0.625 True
# EPISODE 92 rew 1.3125 True
# EPISODE 93 rew 1.1875 True
# hit
# hit
# EPISODE 94 rew 3.0625 True
# hit
# EPISODE 95 rew 3.3125 True
# EPISODE 96 rew 1.875 True
# hit
# hit
# EPISODE 97 rew 2.8125 True
# hit
# EPISODE 98 rew 1.9375 True
# EPISODE 99 rew 0.75 True
# hit
# hit
# hit
# hit
# EPISODE 100 rew 4.4375 True
# hit
# EPISODE 101 rew 2.125 True
# EPISODE 102 rew 1.0 True
# EPISODE 103 rew 1.5 True
# hit
# EPISODE 104 rew 1.8125 True
# EPISODE 105 rew 0.875 True
# hit
# EPISODE 106 rew 1.8125 True
# EPISODE 107 rew 1.1875 True
# EPISODE 108 rew 1.375 True
# hit
# EPISODE 109 rew 2.0 True
# EPISODE 110 rew 2.3125 True
# EPISODE 111 rew 0.9375 True
# hit
# EPISODE 112 rew 1.875 True
# hit
# hit
# EPISODE 113 rew 3.0 True
# hit
# EPISODE 114 rew 1.75 True
# hit
# EPISODE 115 rew 2.5625 True
# EPISODE 116 rew 1.1875 True
# hit
# EPISODE 117 rew 2.1875 True
# EPISODE 118 rew 1.5 True
# hit
# hit
# hit
# EPISODE 119 rew 4.0625 True
# EPISODE 120 rew 0.9375 True
# EPISODE 121 rew 2.0 True
# EPISODE 122 rew 1.25 True
# EPISODE 123 rew 1.375 True
# hit
# EPISODE 124 rew 1.9375 True
# hit
# EPISODE 125 rew 2.0625 True
# EPISODE 126 rew 0.875 True
# hit
# hit
# hit
# hit
# EPISODE 127 rew 5.0625 True
# EPISODE 128 rew 1.0625 True
# EPISODE 129 rew 1.3125 True
# EPISODE 130 rew 1.1875 True
# hit
# EPISODE 131 rew 2.8125 True
# hit
# EPISODE 132 rew 1.25 True
# EPISODE 133 rew 1.8125 True
# hit
# EPISODE 134 rew 1.5625 True
# hit
# EPISODE 135 rew 3.125 True
# EPISODE 136 rew 1.375 True
# hit
# EPISODE 137 rew 3.0 True
# EPISODE 138 rew 0.4375 True
# EPISODE 139 rew 1.3125 True
# hit
# EPISODE 140 rew 2.5 True
# report 2.1059397163120566
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dc400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dc400>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dc400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dc400>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dca90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dca90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dca90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f70800dca90>>: AttributeError: module 'gast' has no attribute 'Num'
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# hit
# ESIMATION 4
# hit
# EPISODE 0 rew 2.625 True
# hit
# EPISODE 1 rew 1.9375 True
# hit
# EPISODE 2 rew 1.5625 True
# EPISODE 3 rew 0.9375 True
# hit
# EPISODE 4 rew 2.0 True
# EPISODE 5 rew 2.3125 True
# EPISODE 6 rew 0.75 True
# hit
# hit
# EPISODE 7 rew 2.6875 True
# EPISODE 8 rew 1.5 True
# EPISODE 9 rew 1.6875 True
# hit
# EPISODE 10 rew 2.0 True
# EPISODE 11 rew 1.0 True
# EPISODE 12 rew 1.125 True
# EPISODE 13 rew 1.375 True
# hit
# EPISODE 14 rew 1.5625 True
# hit
# EPISODE 15 rew 1.625 True
# EPISODE 16 rew 1.6875 True
# hit
# EPISODE 17 rew 1.875 True
# EPISODE 18 rew 1.75 True
# EPISODE 19 rew 0.6875 True
# hit
# hit
# EPISODE 20 rew 3.1875 True
# EPISODE 21 rew 1.4375 True
# hit
# hit
# EPISODE 22 rew 2.75 True
# EPISODE 23 rew 0.875 True
# EPISODE 24 rew 1.75 True
# hit
# EPISODE 25 rew 2.5 True
# EPISODE 26 rew 2.0625 True
# EPISODE 27 rew 1.0625 True
# hit
# hit
# hit
# EPISODE 28 rew 3.5 True
# EPISODE 29 rew 1.5 True
# hit
# EPISODE 30 rew 2.25 True
# EPISODE 31 rew 1.5625 True
# EPISODE 32 rew 1.6875 True
# hit
# hit
# EPISODE 33 rew 3.3125 True
# hit
# EPISODE 34 rew 2.875 True
# EPISODE 35 rew 1.1875 True
# hit
# EPISODE 36 rew 2.0 True
# hit
# hit
# hit
# hit
# EPISODE 37 rew 4.9375 True
# EPISODE 38 rew 1.9375 True
# hit
# hit
# hit
# EPISODE 39 rew 5.4375 True
# EPISODE 40 rew 1.625 True
# EPISODE 41 rew 1.3125 True
# EPISODE 42 rew 1.75 True
# EPISODE 43 rew 1.5 True
# hit
# EPISODE 44 rew 1.9375 True
# hit
# hit
# EPISODE 45 rew 4.1875 True
# hit
# EPISODE 46 rew 2.25 True
# hit
# hit
# EPISODE 47 rew 2.5 True
# hit
# hit
# EPISODE 48 rew 2.1875 True
# EPISODE 49 rew 1.0 True
# EPISODE 50 rew 1.4375 True
# EPISODE 51 rew 0.6875 True
# EPISODE 52 rew 1.625 True
# hit
# hit
# EPISODE 53 rew 2.3125 True
# EPISODE 54 rew 2.1875 True
# hit
# EPISODE 55 rew 1.75 True
# hit
# EPISODE 56 rew 1.9375 True
# hit
# EPISODE 57 rew 1.6875 True
# hit
# EPISODE 58 rew 1.5625 True
# hit
# EPISODE 59 rew 1.1875 True
# EPISODE 60 rew 1.3125 True
# hit
# EPISODE 61 rew 2.1875 True
# hit
# EPISODE 62 rew 2.9375 True
# EPISODE 63 rew 2.4375 True
# hit
# EPISODE 64 rew 2.3125 True
# hit
# EPISODE 65 rew 2.125 True
# EPISODE 66 rew 1.9375 True
# EPISODE 67 rew 0.875 True
# hit
# EPISODE 68 rew 2.5 True
# EPISODE 69 rew 1.6875 True
# hit
# EPISODE 70 rew 1.75 True
# hit
# hit
# EPISODE 71 rew 3.3125 True
# EPISODE 72 rew 1.5 True
# EPISODE 73 rew 1.3125 True
# hit
# hit
# EPISODE 74 rew 4.125 True
# EPISODE 75 rew 0.9375 True
# hit
# EPISODE 76 rew 1.5 True
# hit
# hit
# EPISODE 77 rew 3.1875 True
# EPISODE 78 rew 1.75 True
# EPISODE 79 rew 0.9375 True
# hit
# hit
# EPISODE 80 rew 3.8125 True
# hit
# hit
# hit
# hit
# hit
# EPISODE 81 rew 5.9375 True
# EPISODE 82 rew 1.375 True
# hit
# hit
# hit
# hit
# EPISODE 83 rew 4.9375 True
# hit
# EPISODE 84 rew 1.8125 True
# EPISODE 85 rew 1.625 True
# hit
# hit
# hit
# EPISODE 86 rew 4.3125 True
# EPISODE 87 rew 2.375 True
# hit
# EPISODE 88 rew 3.5 True
# hit
# EPISODE 89 rew 2.375 True
# EPISODE 90 rew 1.4375 True
# hit
# EPISODE 91 rew 2.25 True
# hit
# hit
# EPISODE 92 rew 2.375 True
# hit
# EPISODE 93 rew 1.75 True
# hit
# hit
# hit
# EPISODE 94 rew 3.875 True
# EPISODE 95 rew 0.625 True
# hit
# hit
# hit
# EPISODE 96 rew 4.5 True
# EPISODE 97 rew 1.5625 True
# EPISODE 98 rew 1.8125 True
# hit
# EPISODE 99 rew 2.4375 True
# EPISODE 100 rew 1.625 True
# hit
# EPISODE 101 rew 2.4375 True
# hit
# hit
# EPISODE 102 rew 2.3125 True
# hit
# EPISODE 103 rew 1.75 True
# EPISODE 104 rew 0.8125 True
# hit
# EPISODE 105 rew 2.625 True
# hit
# EPISODE 106 rew 3.4375 True
# EPISODE 107 rew 2.0625 True
# hit
# hit
# hit
# EPISODE 108 rew 3.75 True
# hit
# EPISODE 109 rew 2.0625 True
# hit
# hit
# EPISODE 110 rew 2.9375 True
# hit
# hit
# EPISODE 111 rew 2.4375 True
# hit
# EPISODE 112 rew 2.4375 True
# EPISODE 113 rew 0.9375 True
# hit
# EPISODE 114 rew 2.6875 True
# EPISODE 115 rew 0.9375 True
# hit
# EPISODE 116 rew 2.625 True
# EPISODE 117 rew 1.4375 True
# hit
# EPISODE 118 rew 2.0 True
# EPISODE 119 rew 0.875 True
# EPISODE 120 rew 2.0 True
# EPISODE 121 rew 0.5625 True
# hit
# hit
# EPISODE 122 rew 3.5 True
# EPISODE 123 rew 1.3125 True
# EPISODE 124 rew 1.0 True
# EPISODE 125 rew 1.5 True
# EPISODE 126 rew 2.3125 True
# hit
# hit
# EPISODE 127 rew 2.9375 True
# hit
# EPISODE 128 rew 2.0625 True
# EPISODE 129 rew 1.75 True
# hit
# EPISODE 130 rew 2.25 True
# EPISODE 131 rew 1.3125 True
# hit
# EPISODE 132 rew 1.6875 True
# EPISODE 133 rew 1.9375 True
# EPISODE 134 rew 2.0 True
# hit
# EPISODE 135 rew 2.875 True
# EPISODE 136 rew 2.1875 True
# hit
# EPISODE 137 rew 1.8125 True
# hit
# hit
# EPISODE 138 rew 2.625 True
# EPISODE 139 rew 1.5625 True
# EPISODE 140 rew 0.25 True
# report 2.085549645390071

# %%
plt.plot(rew_episodes)

# %%
np.mean(rew_episodes)
# Out:
# 2.085549645390071

# %%
report
# Out:
# [2.2597517730496453,
#  2.0452127659574466,
#  1.9423758865248226,
#  2.1059397163120566,
#  2.085549645390071]

# %%
#ppo. 100 эпизодов, но вначале 10к тактов обучения. [525.8156, 129.36171, 317.30496, 399.85815, 68.085106]
#ppo. 100 эпизодов, вначале 0 тактов обучения. [194.75177, 211.63121, 211.77306, 205.10638, 201.56029]
Тестовая среда: https://gym.openai.com/envs/Seaquest-ram-v0/

ppo-A: 100 эпизодов, но вначале 10к тактов обучения.
ppo-B: 100 эпизодов, но вначале 0 тактов обучения.
    
Счёт:
'a2c': [67.0, 78.6, 14.4],
 'ddqn': [109.6, 108.4, 147.6],
 'random': [100.0, 102.2, 102.2],
'ppo-A':[525.8156, 129.36171, 317.30496, 399.85815, 68.085106],
'ppo-B':[194.75177, 211.63121, 211.77306, 205.10638, 201.56029]
